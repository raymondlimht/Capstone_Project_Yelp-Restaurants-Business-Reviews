# %% [markdown]
# ## Problem Statements

# %% [markdown]
# The F&B space has witnessed massive growth in the past few years. Opportunities aside, F&B sector also operating in a competitive environment with the increase in numbers of restaurants.
# The goal of the project is to utilize user reviews data to help business owners understand why a business has good/bad ratings. One could learn, exploit and improve the weaknesses of a restaurant and thus get a business advantage. Develop a classification model based on restaurants attributes to predict if a business will be closed. This enables investors to access the risk before investing in a restaurant.

# %%
# import libraries
import pandas as pd    
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates
import numpy as np
import seaborn as sns

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import re
from sklearn.metrics import accuracy_score

from datetime import datetime

import pickle

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ## Load data

# %%
restaurants = pd.read_pickle('./data/restaurants_data_raw.pkl')

# %%
# reset index
restaurants = restaurants.reset_index()

# %%
restaurants.head()
# Out:
#    index             business_id                     name  \
# 0      1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX
# 1     12  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs
# 2     26  hcRxdDg7DYryCxCoI8ySQA        Longwood Galleria
# 3     29  jGennaZUr2MsJyRhijNBfA          Legal Sea Foods
# 4     35  iPD8BBvea6YldQZPHzVrSQ          Espresso Minute
#
#                 address      city state postal_code   latitude   longitude  \
# 0   7000 NE Airport Way  Portland    OR       97218  45.588906 -122.593331
# 1         474 Lowell St   Peabody    MA       01960  42.541155  -70.973438
# 2  340-350 Longwood Ave    Boston    MA       02215  42.338544  -71.106842
# 3       1 Harborside Dr    Boston    MA       02128  42.363442  -71.025781
# 4          334 Mass Ave    Boston    MA       02115  42.342673  -71.084239
#
#    stars  review_count  is_open  \
# 0    4.0           126        1
# 1    4.0            39        1
# 2    2.5            24        1
# 3    3.5           856        1
# 4    4.5             7        0
#
#                                           attributes  \
# 0  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 1  {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# 2  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 3  {'NoiseLevel': 'u'average'', 'BikeParking': 'F...
# 4  {'NoiseLevel': ''quiet'', 'GoodForKids': 'True...
#
#                                           categories  \
# 0  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 1                           Food, Pizza, Restaurants
# 2            Restaurants, Shopping, Shopping Centers
# 3  Sandwiches, Food, Restaurants, Breakfast & Bru...
# 4  Creperies, Restaurants, Food, Coffee & Tea, Br...
#
#                                                hours
# 0  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 1  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2  {'Monday': '6:30-22:0', 'Tuesday': '6:30-22:0'...
# 3  {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
# 4  {'Tuesday': '8:0-20:0', 'Wednesday': '8:0-20:0...

# %%
# remove index column
restaurants.drop(labels='index',axis=1)
# Out:
#                   business_id                     name  \
# 0      tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX
# 1      HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs
# 2      hcRxdDg7DYryCxCoI8ySQA        Longwood Galleria
# 3      jGennaZUr2MsJyRhijNBfA          Legal Sea Foods
# 4      iPD8BBvea6YldQZPHzVrSQ          Espresso Minute
# ...                       ...                      ...
# 18087  cgNDiWCaSlqqxx1A6r65bA               Hop N Cork
# 18088  yQL8SrSETbbCI1U5esVJQw      Ciao! Pizza & Pasta
# 18089  _-nynGfhsMVVWWbAZ6YhTw            The Jury Room
# 18090  Zl6SUy6x9jqjRu2HbtEO6A     Split Dine and Drink
# 18091  GB75wPibj3IjNauaoCxyGA              Havana Cafe
#
#                            address         city state postal_code   latitude  \
# 0              7000 NE Airport Way     Portland    OR       97218  45.588906
# 1                    474 Lowell St      Peabody    MA       01960  42.541155
# 2             340-350 Longwood Ave       Boston    MA       02215  42.338544
# 3                  1 Harborside Dr       Boston    MA       02128  42.363442
# 4                     334 Mass Ave       Boston    MA       02115  42.342673
# ...                            ...          ...   ...         ...        ...
# 18087  17450 Lower Boones Ferry Rd  Lake Oswego    OR       97035  45.399154
# 18088               59 Williams St      Chelsea    MA       02150  42.389221
# 18089               39 Cottage Ave       Quincy    MA       02269  42.249118
# 18090        7335 SW Bridgeport Rd       Tigard    OR       97224  45.394457
# 18091               910 NW 14th St     Portland    OR       97209  45.529647
#
#         longitude  stars  review_count  is_open  \
# 0     -122.593331    4.0           126        1
# 1      -70.973438    4.0            39        1
# 2      -71.106842    2.5            24        1
# 3      -71.025781    3.5           856        1
# 4      -71.084239    4.5             7        0
# ...           ...    ...           ...      ...
# 18087 -122.737600    4.0           137        1
# 18088  -71.040882    5.0           733        1
# 18089  -71.001071    3.0            30        0
# 18090 -122.752535    2.0            48        0
# 18091 -122.685153    4.0            10        1
#
#                                               attributes  \
# 0      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 1      {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# 2      {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 3      {'NoiseLevel': 'u'average'', 'BikeParking': 'F...
# 4      {'NoiseLevel': ''quiet'', 'GoodForKids': 'True...
# ...                                                  ...
# 18087  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 18088  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 18089  {'BusinessParking': '{'garage': False, 'street...
# 18090  {'RestaurantsDelivery': 'False', 'GoodForKids'...
# 18091  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
#
#                                               categories  \
# 0      Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 1                               Food, Pizza, Restaurants
# 2                Restaurants, Shopping, Shopping Centers
# 3      Sandwiches, Food, Restaurants, Breakfast & Bru...
# 4      Creperies, Restaurants, Food, Coffee & Tea, Br...
# ...                                                  ...
# 18087  Nightlife, Wine Bars, Beer Bar, Bars, Restaura...
# 18088                        Restaurants, Pizza, Italian
# 18089             Restaurants, American (New), Nightlife
# 18090  American (Traditional), Desserts, American (Ne...
# 18091              Cuban, Sandwiches, Restaurants, Cafes
#
#                                                    hours
# 0      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 1      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2      {'Monday': '6:30-22:0', 'Tuesday': '6:30-22:0'...
# 3      {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...
# 4      {'Tuesday': '8:0-20:0', 'Wednesday': '8:0-20:0...
# ...                                                  ...
# 18087  {'Monday': '0:0-0:0', 'Tuesday': '16:0-20:0', ...
# 18088  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 18089  {'Monday': '11:30-1:0', 'Tuesday': '11:30-1:0'...
# 18090  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 18091                                               None
#
# [18092 rows x 14 columns]

# %%
restaurants.shape
# Out:
# (18092, 15)

# %%
restaurants.describe()
# Out:
#                index      latitude     longitude         stars  review_count  \
# count   18092.000000  18092.000000  18092.000000  18092.000000  18092.000000
# mean    80462.817101     43.663324    -92.380952      3.596065    122.194174
# std     46167.597745      1.546812     25.426747      0.749110    237.555356
# min         1.000000     42.100171   -122.898977      1.000000      5.000000
# 25%     40827.750000     42.351780   -122.651327      3.000000     19.000000
# 50%     80860.500000     42.478496    -71.181757      3.500000     53.000000
# 75%    119909.500000     45.508249    -71.069529      4.000000    138.000000
# max    160583.000000     45.642123     71.113271      5.000000   9185.000000
#
#             is_open
# count  18092.000000
# mean       0.598386
# std        0.490238
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
restaurants.dtypes
# Out:
# index             int64
# business_id      object
# name             object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# attributes       object
# categories       object
# hours            object
# dtype: object

# %%
user_reviews = pd.read_pickle('./data/users_review_raw.pkl')

# %%
user_reviews.head()
# Out:
#                  review_id                 user_id             business_id  \
# 0   lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 5   J4a2TuhDasjn2k3wWtHZnQ  RNm_RWkcd02Li2mKPRe7Eg  xGXzsc-hzam-VArK6eTvtw
# 6   28gGfkLs3igtjVy61lh77Q  Q8c91v7luItVB0cMFF_mRA  EXOsmAB1s71WePlQk0WZrA
# 9   KKVFopqzcVfcubIBxmIjVA  99RsBrARhhx60UnAC4yDoA  EEHhKSxUvJkoPSzeGKkpVg
# 18  btNWW2kdJYfwpTDyzJO3Iw  DECuRZwkUw8ELQZfNGef2Q  zmZ3HkVCeZPBefJJxzdJ7A
#
#     stars  useful  funny  cool  \
# 0     4.0       3      1     1
# 5     1.0       2      0     0
# 6     2.0       0      0     0
# 9     5.0       0      0     0
# 18    4.0       0      0     0
#
#                                                  text                 date
# 0   Apparently Prides Osteria had a rough summer a...  2014-10-11 03:34:02
# 5   This place used to be a cool, chill place. Now...  2018-01-21 04:41:03
# 6   The setting is perfectly adequate, and the foo...  2006-04-16 02:58:44
# 9   I work in the Pru and this is the most afforda...  2014-05-07 18:10:21
# 18  Nothing special but good enough.  I like anoth...  2012-12-04 04:29:47

# %%
# reset index
user_reviews = user_reviews.reset_index()

# %%
# Check missing value
user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2282296 entries, 0 to 2282295
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   index        int64
#  1   review_id    object
#  2   user_id      object
#  3   business_id  object
#  4   stars        float64
#  5   useful       int64
#  6   funny        int64
#  7   cool         int64
#  8   text         object
#  9   date         object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 174.1+ MB

# %% [markdown]
# ## Cleaning and pre-process restaurant ['categories'] columns

# %%
# Identify categories and count the categories by restaurant
business_overall = restaurants.assign(categories = restaurants.categories.str.split(', ')).explode('categories')
cat = business_overall.categories.value_counts()
cat = cat.to_frame().reset_index()
cat.columns = ['Categories', 'Count']

# %%
cat['Categories'].unique()
# Out:
# array(['Restaurants', 'Food', 'Nightlife', 'Bars', 'Sandwiches', 'Pizza',
#        'American (Traditional)', 'Breakfast & Brunch', 'American (New)',
#        'Coffee & Tea', 'Italian', 'Mexican', 'Burgers', 'Fast Food',
#        'Chinese', 'Cafes', 'Seafood', 'Event Planning & Services',
#        'Salad', 'Food Trucks', 'Japanese', 'Bakeries', 'Food Stands',
#        'Specialty Food', 'Asian Fusion', 'Delis', 'Thai', 'Caterers',
#        'Sushi Bars', 'Cocktail Bars', 'Desserts', 'Pubs', 'Mediterranean',
#        'Vegetarian', 'Vegan', 'Wine & Spirits', 'Beer', 'Gluten-Free',
#        'Sports Bars', 'Chicken Wings', 'Vietnamese', 'Lounges',
#        'Barbeque', 'Wine Bars', 'Soup', 'Arts & Entertainment', 'Diners',
#        'Juice Bars & Smoothies', 'Ice Cream & Frozen Yogurt',
#        'Middle Eastern', 'Indian', 'Steakhouses', 'Latin American',
#        'Bagels', 'Korean', 'Food Delivery Services', 'Grocery',
#        'Street Vendors', 'Venues & Event Spaces', 'Noodles', 'Shopping',
#        'Greek', 'Beer Bar', 'Comfort Food', 'Ethnic Food', 'French',
#        'Tapas/Small Plates', 'Caribbean', 'Donuts', 'Hot Dogs',
#        'Music Venues', 'Tacos', 'Breweries', 'Local Flavor', 'Gastropubs',
#        'Tex-Mex', 'Halal', 'Buffets', 'Home Services', 'Southern',
#        'Dive Bars', 'Irish', 'Bubble Tea', 'Damage Restoration', 'Ramen',
#        'Hotels & Travel', 'Pakistani', 'Tapas Bars', 'Local Services',
#        'Spanish', 'Wraps', 'Hawaiian', 'Hotels', 'Karaoke', 'Active Life',
#        'Brazilian', 'Convenience Stores', 'Dim Sum', 'Chicken Shop',
#        'Cajun/Creole', 'Szechuan', 'Meat Shops', 'Taiwanese', 'Soul Food',
#        'Dance Clubs', 'Creperies', 'Contractors', 'Modern European',
#        'Seafood Markets', 'Lebanese', 'Hot Pot', 'Fish & Chips',
#        'Internet Cafes', 'Cheesesteaks', 'Falafel', 'Pasta Shops',
#        'Cantonese', 'African', 'Food Court', 'Jazz & Blues',
#        'Party & Event Planning', 'Coffee Roasteries', 'Poke', 'German',
#        'Professional Services', 'Health Markets', 'Irish Pub',
#        'Fruits & Veggies', 'Brewpubs', 'Persian/Iranian', 'Acai Bowls',
#        'Turkish', 'Kosher', 'Imported Food', 'Salvadoran', 'Tea Rooms',
#        'Peruvian', 'Waffles', 'Himalayan/Nepalese', 'Carpet Cleaning',
#        'Ethiopian', 'Organic Stores', 'Home Cleaning', 'Cupcakes',
#        'Pool Halls', 'Custom Cakes', 'Farmers Market', 'Live/Raw Food',
#        'Cheese Shops', 'Dominican', 'Moroccan', 'Pan Asian', 'Butcher',
#        'Cuban', 'Arcades', 'Home & Garden', 'Filipino', 'Beer Gardens',
#        'Colombian', 'Education', 'International Grocery',
#        'Flowers & Gifts', 'Whiskey Bars', 'New Mexican Cuisine',
#        'Art Galleries', 'Portuguese', 'Gelato', 'Painters',
#        'Do-It-Yourself Food', 'Wineries', 'British',
#        'Chocolatiers & Shops', 'Basque', 'Fashion', 'Arts & Crafts',
#        'Cambodian', 'Mongolian', 'Izakaya', 'Patisserie/Cake Shop',
#        'Pop-Up Restaurants', 'Adult Entertainment', 'Cinema', 'Laotian',
#        'Automotive', 'Beauty & Spas', 'Kebab', 'Bowling', 'Gay Bars',
#        'Shaved Ice', 'Russian', 'Performing Arts', 'Polish', 'Egyptian',
#        'Wholesalers', 'Comedy Clubs', 'Wholesale Stores', 'Books', 'Mags',
#        'Music & Video', 'Smokehouse', 'Brasseries', 'Haitian', 'Fondue',
#        'Pets', 'Drugstores', 'Argentine', 'Puerto Rican', 'Teppanyaki',
#        'Conveyor Belt Sushi', 'Home Inspectors', 'Wedding Planning',
#        'Air Duct Cleaning', 'Tours', 'Shopping Centers',
#        'Pressure Washers', 'Plumbing', 'Specialty Schools',
#        'Health & Medical', 'Venezuelan', 'Personal Chefs', 'Empanadas',
#        'Financial Services', 'Restaurant Supplies', 'Gift Shops',
#        'Cafeteria', 'Armenian', 'Kitchen & Bath', 'Scandinavian',
#        'Fitness & Instruction', 'Kids Activities', 'Shanghainese',
#        'Hookah Bars', 'Belgian', 'Office Cleaning', 'Flooring',
#        'Cooking Schools', 'Japanese Curry', 'Carpenters', 'Candy Stores',
#        'Art Restoration', 'Golf', 'Cideries', 'Roofing',
#        'Public Services & Government', 'Drywall Installation & Repair',
#        'Bed & Breakfast', 'Burmese', 'Community Service/Non-Profit',
#        'Interior Design', 'Wine Tasting Room', 'Beverage Store',
#        'Antiques', 'Arabian', 'Sporting Goods', 'Florists',
#        'Social Clubs', 'Banks & Credit Unions', 'Cooking Classes',
#        'Environmental Abatement', 'Indonesian', 'Real Estate',
#        'Refinishing Services', 'Themed Cafes', 'Kombucha',
#        'Masonry/Concrete', 'Trinidadian', 'Decks & Railing', 'Handyman',
#        'Singaporean', 'Pretzels', 'Tiki Bars', 'Tobacco Shops',
#        "Women's Clothing", 'Environmental Testing', 'Somali',
#        'Heating & Air Conditioning/HVAC', 'Macarons', 'Delicatessen',
#        'Indoor Playcentre', 'Australian', 'Piano Bars',
#        'Religious Organizations', 'Hobby Shops', 'Malaysian', 'Tiling',
#        'Hair Salons', 'Water Heater Installation/Repair',
#        'Nurseries & Gardening', 'Champagne Bars', 'Bookstores',
#        'Dinner Theater', 'Ethnic Grocery', 'Gas Stations', 'Appliances',
#        'Herbs & Spices', 'Department Stores', 'Afghan', 'Tabletop Games',
#        'Windows Installation', 'Food Tours', 'Grout Services', 'Day Spas',
#        'Cabinetry', 'Junk Removal & Hauling', 'Hong Kong Style Cafe',
#        'Casinos', 'Snow Removal', 'Siding', 'Hungarian', 'Poutineries',
#        'Recreation Centers', 'Walking Tours', 'Bikes', 'Gutter Services',
#        'Ukrainian', 'Art Classes', 'Carpeting', 'Pet Services',
#        'Furniture Repair', 'Festivals', 'Amusement Parks', 'Museums',
#        'Honduran', 'Pop-up Shops', 'Boating', 'Transportation',
#        "Men's Clothing", 'Real Estate Services', 'Bistros', 'Bangladeshi',
#        'Jewelry', 'Window Washing', 'Sports Wear',
#        'Dry Cleaning & Laundry', 'Trainers', 'Pet Stores',
#        'Eatertainment', 'Furniture Reupholstery', 'Glass & Mirrors',
#        'Senegalese', 'Auto Repair', 'IT Services & Computer Repair',
#        'Historical Tours', 'Videos & Video Game Rental', 'Austrian',
#        'Boat Charters', 'Adult Education', 'Pancakes', 'Accessories',
#        'Fences & Gates', 'Strip Clubs', 'Gyms', 'Scottish', 'Framing',
#        'Waterproofing', 'Playgrounds', 'Guamanian', 'Electronics Repair',
#        'Landmarks & Historical Buildings', 'Public Markets', 'Parking',
#        'Mountain Biking', 'Tuscan', 'Bike Repair/Maintenance',
#        'Vitamins & Supplements', 'Home Decor', 'Laser Tag',
#        'Laundry Services', 'Guest Houses', 'Cards & Stationery',
#        'Building Supplies', 'Uzbek', 'Mobile Phones', 'Hair Stylists',
#        'Sports Clubs', 'Sewing & Alterations', 'Colleges & Universities',
#        'Nutritionists', 'Hair Extensions', 'Appliances & Repair',
#        'Mini Golf', 'Mobile Phone Repair', 'Pet Adoption', 'Parks',
#        'Bartenders', 'Syrian', 'Door Sales/Installation', 'Toy Stores',
#        'Party Equipment Rentals', 'Ethical Grocery', 'CSA', 'Sri Lankan',
#        'Wigs', 'Golf Lessons', 'Demolition Services', 'Nail Salons',
#        'Motorcycle Gear', 'Paint & Sip', 'Hair Removal',
#        'Foundation Repair', 'Airports', 'Electricians', 'Comic Books',
#        'Barbers', 'Coffee & Tea Supplies', 'Educational Services',
#        'Kiosk', 'Tennis', 'Synagogues', 'Pub Food', 'Septic Services',
#        'Child Care & Day Care', 'Polynesian', 'Watches', 'Surf Shop',
#        'Excavation Services', 'Weight Loss Centers', 'Art Schools',
#        'Architects', 'Art Supplies', 'Waxing', 'Keys & Locksmiths',
#        'South African', 'Carpet Installation', 'Beer Tours', 'Massage',
#        'Tree Services', 'Resorts', 'Photography Stores & Services',
#        'Shoe Stores', 'Cigar Bars', 'Apartments', 'DJs', 'Catalan',
#        'Post Offices', 'Life Coach', 'Pet Sitting', 'Speakeasies',
#        'Home Organization', 'Pharmacy', 'Auto Detailing', 'Vinyl Records',
#        'Sicilian', 'Vape Shops', 'Electronics', 'Wine Tasting Classes',
#        'Animal Shelters', 'Tasting Classes', 'Gold Buyers', 'Movers',
#        'Rugs', 'Tires', 'Churches', 'Airport Lounges',
#        'Cannabis Dispensaries', 'Furniture Stores', 'Boat Tours',
#        'Yelp Events', 'Insulation Installation', 'Ticket Sales',
#        'Dentists', 'Used', 'Coffeeshops', "Men's Hair Salons",
#        'Shoe Shine', 'Auto Glass Services', 'Disc Golf',
#        'Supernatural Readings', 'Watch Repair', 'Spiritual Shop',
#        'Biohazard Cleanup', 'Kitchen Supplies', 'Tableware',
#        'Newspapers & Magazines', 'Internet Service Providers',
#        'Talent Agencies', "Children's Clothing", 'Lakes',
#        'Wildlife Control', 'Used Bookstore', 'Botanical Gardens',
#        'Roof Inspectors', 'Awnings', 'Cultural Center',
#        'Windshield Installation & Repair', 'Distilleries',
#        'Hardware Stores', 'Czech/Slovakian', 'Czech', 'Wine Tours',
#        'Rotisserie Chicken', 'Hazardous Waste Disposal',
#        'Motorcycle Dealers', 'Travel Services',
#        'Portable Toilet Services', 'Fireplace Services', 'Pest Control',
#        'Outlet Stores', 'Art Museums', 'Christmas Trees',
#        'Fischbroetchen', 'Team Building Activities', 'Go Karts',
#        'Mobile Phone Accessories', 'Dance Restaurants', 'Car Dealers',
#        'Mauritius', 'Auto Upholstery', 'Food Safety Training',
#        'Stadiums & Arenas', 'Veterinarians', 'Skin Care', 'Adult',
#        'Cannabis Clinics', 'Surfing', 'Petting Zoos', 'Iberian',
#        'Traditional Chinese Medicine', 'Bike Rentals', 'Bingo Halls',
#        'Laundromat', 'Public Relations', 'Diamond Buyers',
#        'Telecommunications', 'Departments of Motor Vehicles',
#        'Blow Dry/Out Services', 'Periodontists', 'Airport Shuttles',
#        'Zoos', 'Brewing Supplies', 'Auction Houses', 'Irrigation',
#        'Horse Racing', 'Shipping Centers',
#        'Vocational & Technical School', 'Party Bus Rentals',
#        'Estate Liquidation', 'Rest Stops', 'Grilling Equipment',
#        'Community Centers', 'Beaches', 'Utilities', 'Sardinian',
#        'Art Tours', 'Pet Groomers', 'Mass Media', 'Jewish',
#        'Water Delivery', 'Dog Walkers', 'Limos', 'Wallpapering',
#        'Appraisal Services', 'Endodontists', 'Paint-Your-Own Pottery',
#        'Country Clubs', 'Lighting Fixtures & Equipment', 'Oral Surgeons',
#        'Cabaret', 'Musicians', 'Vermouth Bars', 'Web Design',
#        'Bike Parking', 'Skating Rinks', 'Doctors',
#        'Auto Parts & Supplies', 'Elementary Schools', 'Eritrean',
#        'Pool & Billiards', 'Test Preparation', 'Chimney Sweeps',
#        'Dog Parks', 'Paddleboarding', 'Parent Cafes', 'Train Stations',
#        'Motorcycle Repair', 'Party Bike Rentals', 'Pawn Shops',
#        'Kiteboarding', 'Glass Blowing', 'Costumes', 'Clock Repair',
#        'Property Management', 'Vintage & Consignment', 'Yoga',
#        'Music & DVDs', 'Bridal', 'Georgian', 'Soccer',
#        'Printing Services', 'Swiss Food', 'Party Supplies',
#        'Wedding Chapels', 'Metal Fabricators', 'Taxis', 'Pet Hospice',
#        'Food Banks', 'Honey', 'Hair Loss Centers', 'Axe Throwing',
#        'Discount Store', 'Car Wash', 'Medical Spas', 'Calabrian',
#        'Print Media', 'Dry Cleaning', 'Massage Therapy', 'Bar Crawl',
#        'Accountants'], dtype=object)

# %%
def assign_cat(label,cat):
    restaurants.loc[restaurants.categories.str.contains(label),'category'] = cat

# %%
# Recreate categories of restaurants
# Less significant
assign_cat('Food Stands','Streets')
assign_cat('Food Trucks','Streets')
assign_cat('Nightlife','Nightlife')
assign_cat('Cuban','Cuban')
assign_cat('Asian Fusion','Fusion')
assign_cat('Fast Food','Fast_Food')
assign_cat('Streets','Streets')


# More significant
assign_cat('Cafes','Cafes')
assign_cat('Coffee & Tea','Cafes')
assign_cat('Wine','Bars')
assign_cat('Bars','Bars')
assign_cat('Bakeries','Bakeries')
assign_cat('Pizza','Western')
assign_cat('Burgers','Western')


assign_cat('American','American')
assign_cat('Mexican','Mexican')
assign_cat('Tacos','Mexican')
assign_cat('Thai','Thai')
assign_cat('Japanese','Japanese')
assign_cat('Sushi','Japanese')
assign_cat('Vegetarian','Vegetarian/Vegan')
assign_cat('Vegan','Vegetarian/Vegan')
assign_cat('Italian','Italian')
assign_cat('Chinese','Chinese')
assign_cat('Mediterranean','Mediterranean')
assign_cat('French','French')
assign_cat('Vietnamese','Vietnamese')
assign_cat('Greek','Greek')
assign_cat('Indian','Indian')
assign_cat('Korean','Korean')
assign_cat('Hawaiian','Hawaiian')
assign_cat('African','African')
assign_cat('Spanish','Spanish')
assign_cat('German','German')
assign_cat('Middle_eastern','Middle_eastern')
assign_cat('Filipino','Filipino')

# %%
restaurants['category'].isnull().sum()
# Out:
# 1836

# %%
# Drop categories
restaurants.drop(columns='categories',inplace=True)

# %%
restaurants[restaurants['category'].isnull()]
# Out:
#         index             business_id                     name  \
# 2          26  hcRxdDg7DYryCxCoI8ySQA        Longwood Galleria
# 9          68  G6xF2EGY-F04iFhq5sX8MQ          MJB Restoration
# 20        187  fDJm1OQWJg6XyuVTcxoemg               The Barrel
# 23        197  EJ58GOWZplYJkj4TkDuSXw   D'angelo Sandwich Shop
# 27        221  fD9EopsUWvimsi4eaS7uMA     The Wheelhouse Diner
# ...       ...                     ...                      ...
# 18034  160015  bkv4EZ5RYRvZITO1PaOaNg            Best Baguette
# 18041  160133  jHg7ZDzcxV2mYyf7XThk9w  King Crab Juicy Seafood
# 18059  160378  znkU8_QJ4Dksd8XUVjXBcg      Fuku Boston Seaport
# 18066  160455  nS8uRoVeqe20VsDDH59jHQ      Boston Foodie Tours
# 18081  160537  ER_VMRSD-9FSbw4SGGNQvA                 Seaplane
#
#                     address      city state postal_code   latitude  \
# 2      340-350 Longwood Ave    Boston    MA       02215  42.338544
# 9                            Portland    OR       97213  45.535283
# 20              613 Main St   Hingham    MA       02043  42.215607
# 23            1277 Broadway    Saugus    MA       01906  42.461100
# 27           453 Hancock St    Quincy    MA       02171  42.272234
# ...                     ...       ...   ...         ...        ...
# 18034       1833 SW 6th Ave  Portland    OR       97201  45.511406
# 18041           180 Main St    Saugus    MA       01906  42.463541
# 18059       43 Northern Ave    Boston    MA       02210  42.353272
# 18066                          Boston    MA       02114  42.365292
# 18081    2266 NW Lovejoy St  Portland    OR       97210  45.529592
#
#         longitude  stars  review_count  is_open  \
# 2      -71.106842    2.5            24        1
# 9     -122.603754    4.5             9        1
# 20     -70.885132    3.5            11        1
# 23     -71.026910    2.0             6        1
# 27     -71.023950    4.0           229        1
# ...           ...    ...           ...      ...
# 18034 -122.682940    3.5            47        1
# 18041  -71.026098    3.5            15        1
# 18059  -71.046872    3.5           182        0
# 18066  -71.064634    5.0            67        1
# 18081 -122.697685    3.5            13        0
#
#                                               attributes  \
# 2      {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 9                          {'ByAppointmentOnly': 'True'}
# 20     {'BusinessParking': '{'garage': False, 'street...
# 23     {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 27     {'HasTV': 'False', 'BusinessParking': '{'garag...
# ...                                                  ...
# 18034  {'GoodForKids': 'False', 'DogsAllowed': 'False...
# 18041  {'WheelchairAccessible': 'True', 'RestaurantsD...
# 18059  {'RestaurantsReservations': 'False', 'HappyHou...
# 18066  {'BusinessParking': '{'garage': True, 'street'...
# 18081  {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#                                                    hours category
# 2      {'Monday': '6:30-22:0', 'Tuesday': '6:30-22:0'...      NaN
# 9                                                   None      NaN
# 20     {'Monday': '6:30-20:0', 'Tuesday': '6:30-20:0'...      NaN
# 23                                                  None      NaN
# 27     {'Wednesday': '5:0-15:0', 'Thursday': '5:0-11:...      NaN
# ...                                                  ...      ...
# 18034                                               None      NaN
# 18041  {'Monday': '0:0-0:0', 'Tuesday': '11:30-22:0',...      NaN
# 18059  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...      NaN
# 18066  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...      NaN
# 18081  {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...      NaN
#
# [1836 rows x 15 columns]

# %%
# Drop 1836 rows null category
restaurants.drop(restaurants[restaurants['category'].isnull()].index, inplace=True)

# %%
restaurants.drop(labels='index', axis=1, inplace=True)

# %%
restaurants.reset_index(inplace=True)

# %%
restaurants.drop(labels='index', axis=1, inplace=True)

# %%
restaurants
# Out:
#                   business_id                           name  \
# 0      tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX
# 1      HPA_qyMEddpAEtFof02ixg            Mr G's Pizza & Subs
# 2      jGennaZUr2MsJyRhijNBfA                Legal Sea Foods
# 3      iPD8BBvea6YldQZPHzVrSQ                Espresso Minute
# 4      jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits
# ...                       ...                            ...
# 16251  cgNDiWCaSlqqxx1A6r65bA                     Hop N Cork
# 16252  yQL8SrSETbbCI1U5esVJQw            Ciao! Pizza & Pasta
# 16253  _-nynGfhsMVVWWbAZ6YhTw                  The Jury Room
# 16254  Zl6SUy6x9jqjRu2HbtEO6A           Split Dine and Drink
# 16255  GB75wPibj3IjNauaoCxyGA                    Havana Cafe
#
#                            address         city state postal_code   latitude  \
# 0              7000 NE Airport Way     Portland    OR       97218  45.588906
# 1                    474 Lowell St      Peabody    MA       01960  42.541155
# 2                  1 Harborside Dr       Boston    MA       02128  42.363442
# 3                     334 Mass Ave       Boston    MA       02115  42.342673
# 4               12429 NE Glisan St     Portland    OR       97230  45.526473
# ...                            ...          ...   ...         ...        ...
# 16251  17450 Lower Boones Ferry Rd  Lake Oswego    OR       97035  45.399154
# 16252               59 Williams St      Chelsea    MA       02150  42.389221
# 16253               39 Cottage Ave       Quincy    MA       02269  42.249118
# 16254        7335 SW Bridgeport Rd       Tigard    OR       97224  45.394457
# 16255               910 NW 14th St     Portland    OR       97209  45.529647
#
#         longitude  stars  review_count  is_open  \
# 0     -122.593331    4.0           126        1
# 1      -70.973438    4.0            39        1
# 2      -71.025781    3.5           856        1
# 3      -71.084239    4.5             7        0
# 4     -122.535323    3.5            19        1
# ...           ...    ...           ...      ...
# 16251 -122.737600    4.0           137        1
# 16252  -71.040882    5.0           733        1
# 16253  -71.001071    3.0            30        0
# 16254 -122.752535    2.0            48        0
# 16255 -122.685153    4.0            10        1
#
#                                               attributes  \
# 0      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 1      {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# 2      {'NoiseLevel': 'u'average'', 'BikeParking': 'F...
# 3      {'NoiseLevel': ''quiet'', 'GoodForKids': 'True...
# 4      {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# ...                                                  ...
# 16251  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 16252  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 16253  {'BusinessParking': '{'garage': False, 'street...
# 16254  {'RestaurantsDelivery': 'False', 'GoodForKids'...
# 16255  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
#
#                                                    hours          category
# 0      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...  Vegetarian/Vegan
# 1      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...           Western
# 2      {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...           Italian
# 3      {'Tuesday': '8:0-20:0', 'Wednesday': '8:0-20:0...             Cafes
# 4      {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...         Nightlife
# ...                                                  ...               ...
# 16251  {'Monday': '0:0-0:0', 'Tuesday': '16:0-20:0', ...          American
# 16252  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...           Italian
# 16253  {'Monday': '11:30-1:0', 'Tuesday': '11:30-1:0'...          American
# 16254  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...          American
# 16255                                               None             Cafes
#
# [16256 rows x 14 columns]

# %% [markdown]
# ## Drop hours columns

# %%
# Drop hours
restaurants.drop(columns='hours', axis=1,inplace=True)

# %% [markdown]
# ## Clean and preprocess `attributes` columns

# %%
# break up dict inside `attributes` columns
df_attr = restaurants['attributes'].apply(pd.Series)
df_attr
# Out:
#       RestaurantsTakeOut RestaurantsAttire GoodForKids BikeParking  \
# 0                   True         u'casual'        True       False
# 1                   True         u'casual'        True        True
# 2                   True         u'casual'        True       False
# 3                   True          'casual'        True        True
# 4                   True          'casual'        True        True
# ...                  ...               ...         ...         ...
# 16251               True          'casual'        True        True
# 16252               True         u'casual'        True       False
# 16253               True          'casual'       False         NaN
# 16254              False          'casual'       False         NaN
# 16255               True               NaN         NaN         NaN
#
#       OutdoorSeating                                           Ambience  \
# 0              False  {'romantic': False, 'intimate': False, 'touris...
# 1               True  {'romantic': False, 'intimate': False, 'classy...
# 2              False  {'touristy': None, 'hipster': False, 'romantic...
# 3               True  {'romantic': False, 'intimate': False, 'classy...
# 4              False  {'romantic': False, 'intimate': False, 'touris...
# ...              ...                                                ...
# 16251           True  {'romantic': False, 'intimate': False, 'classy...
# 16252           True  {'touristy': False, 'hipster': False, 'romanti...
# 16253          False                                                NaN
# 16254           True  {'romantic': False, 'intimate': False, 'touris...
# 16255            NaN                                                NaN
#
#       Caters RestaurantsReservations RestaurantsDelivery  HasTV  ... Corkage  \
# 0       True                   False               False  False  ...     NaN
# 1       True                   False                True   True  ...     NaN
# 2      False                   False               False   True  ...     NaN
# 3       True                   False               False  False  ...     NaN
# 4        NaN                   False               False   True  ...     NaN
# ...      ...                     ...                 ...    ...  ...     ...
# 16251   True                   False                True   True  ...     NaN
# 16252  False                   False               False  False  ...     NaN
# 16253    NaN                    True               False    NaN  ...     NaN
# 16254  False                    True               False   True  ...     NaN
# 16255    NaN                     NaN                True   True  ...     NaN
#
#       BYOB CoatCheck Smoking DriveThru RestaurantsCounterService AgesAllowed  \
# 0      NaN       NaN     NaN       NaN                       NaN         NaN
# 1      NaN       NaN     NaN       NaN                       NaN         NaN
# 2      NaN       NaN     NaN       NaN                       NaN         NaN
# 3      NaN       NaN     NaN       NaN                       NaN         NaN
# 4      NaN       NaN     NaN       NaN                       NaN         NaN
# ...    ...       ...     ...       ...                       ...         ...
# 16251  NaN     False   u'no'       NaN                       NaN         NaN
# 16252  NaN       NaN     NaN       NaN                       NaN         NaN
# 16253  NaN       NaN     NaN       NaN                       NaN         NaN
# 16254  NaN       NaN     NaN       NaN                       NaN         NaN
# 16255  NaN       NaN     NaN       NaN                       NaN         NaN
#
#       DietaryRestrictions Open24Hours HairSpecializesIn
# 0                     NaN         NaN               NaN
# 1                     NaN         NaN               NaN
# 2                     NaN         NaN               NaN
# 3                     NaN         NaN               NaN
# 4                     NaN         NaN               NaN
# ...                   ...         ...               ...
# 16251                 NaN         NaN               NaN
# 16252                 NaN         NaN               NaN
# 16253                 NaN         NaN               NaN
# 16254                 NaN         NaN               NaN
# 16255                 NaN         NaN               NaN
#
# [16256 rows x 38 columns]

# %%
# Calculate the missing percentage for the attrbutes feature
percent_missing = df_attr.isnull().sum() * 100 / len(df_attr)
missing_value_df = pd.DataFrame({'column_name': df_attr.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.sort_values('percent_missing', inplace=True)

# %%
missing_value_df
# Out:
#                                            column_name  percent_missing
# RestaurantsTakeOut                  RestaurantsTakeOut         5.031988
# BusinessAcceptsCreditCards  BusinessAcceptsCreditCards         5.038140
# RestaurantsDelivery                RestaurantsDelivery         6.889764
# BusinessParking                        BusinessParking         7.092766
# RestaurantsPriceRange2          RestaurantsPriceRange2         9.781004
# OutdoorSeating                          OutdoorSeating        10.113189
# RestaurantsReservations        RestaurantsReservations        12.475394
# RestaurantsGoodForGroups      RestaurantsGoodForGroups        14.788386
# Alcohol                                        Alcohol        15.668061
# GoodForKids                                GoodForKids        15.828002
# HasTV                                            HasTV        17.156742
# RestaurantsAttire                    RestaurantsAttire        18.177904
# Ambience                                      Ambience        18.190207
# WiFi                                              WiFi        21.764272
# NoiseLevel                                  NoiseLevel        26.777805
# BikeParking                                BikeParking        28.727854
# Caters                                          Caters        28.887795
# GoodForMeal                                GoodForMeal        43.694636
# RestaurantsTableService        RestaurantsTableService        61.921752
# WheelchairAccessible              WheelchairAccessible        72.244094
# HappyHour                                    HappyHour        73.222195
# DogsAllowed                                DogsAllowed        77.743602
# BusinessAcceptsBitcoin          BusinessAcceptsBitcoin        84.817913
# Music                                            Music        86.681841
# BYOBCorkage                                BYOBCorkage        88.398130
# BestNights                                  BestNights        89.382382
# Corkage                                        Corkage        89.819144
# CoatCheck                                    CoatCheck        90.883366
# GoodForDancing                          GoodForDancing        91.055610
# Smoking                                        Smoking        91.769193
# BYOB                                              BYOB        92.501230
# DriveThru                                    DriveThru        92.667323
# ByAppointmentOnly                    ByAppointmentOnly        92.827264
# RestaurantsCounterService    RestaurantsCounterService        99.846211
# DietaryRestrictions                DietaryRestrictions        99.858514
# Open24Hours                                Open24Hours        99.913878
# AgesAllowed                                AgesAllowed        99.969242
# HairSpecializesIn                    HairSpecializesIn        99.987697

# %%
## Drop restaurant attributes which has more than 30% missing values
attr_drop = list(missing_value_df[missing_value_df['percent_missing'] >= 30].index)
df_attr = df_attr.drop(columns=attr_drop, axis=1)

# %%
# Create functions to extract the dicts stored in attributes, return dataframe with dic keys as columns
    
def str_dict_to_df(series):

    eval_list = []
    for sr in series:
        if not pd.isna(sr):
            eval_list.append(eval(sr))
        else:
            eval_list.append(np.nan)
    
    eval_df = pd.Series(eval_list).apply(pd.Series)  
    
    #drop cols that are all nan
    eval_df = eval_df.dropna(axis=1, how='all')
    
    
    return eval_df

# %%
#store col names
dict_cols_list = []

for col in df_attr:
    #if contains a curly bracket, then assume column is a dict as string
    if df_attr[col].str.contains('{').any():
        dict_cols_list.append(col)
print(dict_cols_list)
# Out:
# ['Ambience', 'BusinessParking']

# %%
#store dataframes from dict nested columns
dict_col_df_list = []

for col in dict_cols_list:
    #apply string to dict evaluation
    temp_df = str_dict_to_df(df_attr[col])
    #append to list
    dict_col_df_list.append(temp_df)

#combine all in one column
dict_col_df = pd.concat(dict_col_df_list, axis=1)
dict_col_df.head()
# Out:
#   casual classy  divey hipster intimate romantic touristy trendy upscale  \
# 0   True  False  False   False    False    False    False  False   False
# 1   True  False  False   False    False    False    False  False   False
# 2   True   True  False   False    False    False     None  False   False
# 3  False  False  False   False    False    False    False  False   False
# 4   True  False  False   False    False    False    False  False   False
#
#   garage    lot street  valet validated
# 0   True  False  False  False     False
# 1  False   True  False  False     False
# 2   True  False  False  False     False
# 3  False  False  False  False     False
# 4  False   True  False  False     False

# %%
dict_col_df.shape
# Out:
# (16256, 14)

# %%
# join the dict_col_df to df_attr, drop ['BusinessParking'] & ['Ambience']
df_attr_conc = pd.concat([df_attr, dict_col_df], axis =1)
df_attr_conc.drop(columns=['BusinessParking','Ambience'],axis=1, inplace = True)

# %%
df_attr_conc
# Out:
#       RestaurantsTakeOut RestaurantsAttire GoodForKids BikeParking  \
# 0                   True         u'casual'        True       False
# 1                   True         u'casual'        True        True
# 2                   True         u'casual'        True       False
# 3                   True          'casual'        True        True
# 4                   True          'casual'        True        True
# ...                  ...               ...         ...         ...
# 16251               True          'casual'        True        True
# 16252               True         u'casual'        True       False
# 16253               True          'casual'       False         NaN
# 16254              False          'casual'       False         NaN
# 16255               True               NaN         NaN         NaN
#
#       OutdoorSeating Caters RestaurantsReservations RestaurantsDelivery  \
# 0              False   True                   False               False
# 1               True   True                   False                True
# 2              False  False                   False               False
# 3               True   True                   False               False
# 4              False    NaN                   False               False
# ...              ...    ...                     ...                 ...
# 16251           True   True                   False                True
# 16252           True  False                   False               False
# 16253          False    NaN                    True               False
# 16254           True  False                    True               False
# 16255            NaN    NaN                     NaN                True
#
#        HasTV RestaurantsGoodForGroups  ... intimate romantic touristy trendy  \
# 0      False                    False  ...    False    False    False  False
# 1       True                     True  ...    False    False    False  False
# 2       True                    False  ...    False    False     None  False
# 3      False                     True  ...    False    False    False  False
# 4       True                     True  ...    False    False    False  False
# ...      ...                      ...  ...      ...      ...      ...    ...
# 16251   True                     True  ...    False    False    False  False
# 16252  False                    False  ...    False    False    False  False
# 16253    NaN                     True  ...      NaN      NaN      NaN    NaN
# 16254   True                     True  ...    False    False    False  False
# 16255   True                      NaN  ...      NaN      NaN      NaN    NaN
#
#       upscale garage    lot street  valet validated
# 0       False   True  False  False  False     False
# 1       False  False   True  False  False     False
# 2       False   True  False  False  False     False
# 3       False  False  False  False  False     False
# 4       False  False   True  False  False     False
# ...       ...    ...    ...    ...    ...       ...
# 16251   False  False   True   True  False     False
# 16252   False  False   True  False  False     False
# 16253     NaN  False  False   True  False     False
# 16254   False   True  False  False   True     False
# 16255     NaN    NaN    NaN    NaN    NaN       NaN
#
# [16256 rows x 29 columns]

# %%
df_attr_conc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16256 entries, 0 to 16255
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RestaurantsTakeOut          15438 non-null  object
#  1   RestaurantsAttire           13301 non-null  object
#  2   GoodForKids                 13683 non-null  object
#  3   BikeParking                 11586 non-null  object
#  4   OutdoorSeating              14612 non-null  object
#  5   Caters                      11560 non-null  object
#  6   RestaurantsReservations     14228 non-null  object
#  7   RestaurantsDelivery         15136 non-null  object
#  8   HasTV                       13467 non-null  object
#  9   RestaurantsGoodForGroups    13852 non-null  object
#  10  BusinessAcceptsCreditCards  15437 non-null  object
#  11  NoiseLevel                  11903 non-null  object
#  12  RestaurantsPriceRange2      14666 non-null  object
#  13  WiFi                        12718 non-null  object
#  14  Alcohol                     13709 non-null  object
#  15  casual                      12831 non-null  object
#  16  classy                      12656 non-null  object
#  17  divey                       12432 non-null  object
#  18  hipster                     12447 non-null  object
#  19  intimate                    12505 non-null  object
#  20  romantic                    12727 non-null  object
#  21  touristy                    12695 non-null  object
#  22  trendy                      12305 non-null  object
#  23  upscale                     12728 non-null  object
#  24  garage                      14651 non-null  object
#  25  lot                         14788 non-null  object
#  26  street                      14670 non-null  object
#  27  valet                       14944 non-null  object
#  28  validated                   14725 non-null  object
# dtypes: object(29)
# memory usage: 3.6+ MB

# %%
df_attr_conc.columns
# Out:
# Index(['RestaurantsTakeOut', 'RestaurantsAttire', 'GoodForKids', 'BikeParking',
#        'OutdoorSeating', 'Caters', 'RestaurantsReservations',
#        'RestaurantsDelivery', 'HasTV', 'RestaurantsGoodForGroups',
#        'BusinessAcceptsCreditCards', 'NoiseLevel', 'RestaurantsPriceRange2',
#        'WiFi', 'Alcohol', 'casual', 'classy', 'divey', 'hipster', 'intimate',
#        'romantic', 'touristy', 'trendy', 'upscale', 'garage', 'lot', 'street',
#        'valet', 'validated'],
#       dtype='object')

# %% [markdown]
# ### Replace 'None' with np.NaN

# %%
df_attr_conc.replace({'True': True, 'False':False, 'None': np.NaN}, inplace = True)

# %% [markdown]
# ### Clean the attributes that begins with u'XXX'

# %%
for col in df_attr_conc:
    print(col)
    print(df_attr_conc[col].unique())
    print(50*'-')
# Out:
# RestaurantsTakeOut
# [True False nan]
# --------------------------------------------------
# RestaurantsAttire
# ["u'casual'" "'casual'" nan "u'formal'" "u'dressy'" "'dressy'" "'formal'"]
# --------------------------------------------------
# GoodForKids
# [True False nan]
# --------------------------------------------------
# BikeParking
# [False True nan]
# --------------------------------------------------
# OutdoorSeating
# [False True nan]
# --------------------------------------------------
# Caters
# [True False nan]
# --------------------------------------------------
# RestaurantsReservations
# [False True nan]
# --------------------------------------------------
# RestaurantsDelivery
# [False True nan]
# --------------------------------------------------
# HasTV
# [False True nan]
# --------------------------------------------------
# RestaurantsGoodForGroups
# [False True nan]
# --------------------------------------------------
# BusinessAcceptsCreditCards
# [True nan False]
# --------------------------------------------------
# NoiseLevel
# ["u'average'" "'average'" "'quiet'" "u'quiet'" nan "u'loud'"
#  "u'very_loud'" "'loud'" "'very_loud'"]
# --------------------------------------------------
# RestaurantsPriceRange2
# ['2' '1' '4' nan '3']
# --------------------------------------------------
# WiFi
# ["u'free'" nan "u'no'" "'free'" "'no'" "u'paid'" "'paid'"]
# --------------------------------------------------
# Alcohol
# ["u'beer_and_wine'" "u'none'" "u'full_bar'" "'none'" nan "'beer_and_wine'"
#  "'full_bar'"]
# --------------------------------------------------
# casual
# [True False nan None]
# --------------------------------------------------
# classy
# [False True nan None]
# --------------------------------------------------
# divey
# [False nan None True]
# --------------------------------------------------
# hipster
# [False None nan True]
# --------------------------------------------------
# intimate
# [False nan None True]
# --------------------------------------------------
# romantic
# [False nan None True]
# --------------------------------------------------
# touristy
# [False None nan True]
# --------------------------------------------------
# trendy
# [False nan None True]
# --------------------------------------------------
# upscale
# [False nan None True]
# --------------------------------------------------
# garage
# [True False nan None]
# --------------------------------------------------
# lot
# [False True nan None]
# --------------------------------------------------
# street
# [False True nan None]
# --------------------------------------------------
# valet
# [False nan True]
# --------------------------------------------------
# validated
# [False nan True None]
# --------------------------------------------------

# %%
df_attr_conc
# Out:
#       RestaurantsTakeOut RestaurantsAttire GoodForKids BikeParking  \
# 0                   True         u'casual'        True       False
# 1                   True         u'casual'        True        True
# 2                   True         u'casual'        True       False
# 3                   True          'casual'        True        True
# 4                   True          'casual'        True        True
# ...                  ...               ...         ...         ...
# 16251               True          'casual'        True        True
# 16252               True         u'casual'        True       False
# 16253               True          'casual'       False         NaN
# 16254              False          'casual'       False         NaN
# 16255               True               NaN         NaN         NaN
#
#       OutdoorSeating Caters RestaurantsReservations RestaurantsDelivery  \
# 0              False   True                   False               False
# 1               True   True                   False                True
# 2              False  False                   False               False
# 3               True   True                   False               False
# 4              False    NaN                   False               False
# ...              ...    ...                     ...                 ...
# 16251           True   True                   False                True
# 16252           True  False                   False               False
# 16253          False    NaN                    True               False
# 16254           True  False                    True               False
# 16255            NaN    NaN                     NaN                True
#
#        HasTV RestaurantsGoodForGroups  ... intimate romantic touristy trendy  \
# 0      False                    False  ...    False    False    False  False
# 1       True                     True  ...    False    False    False  False
# 2       True                    False  ...    False    False     None  False
# 3      False                     True  ...    False    False    False  False
# 4       True                     True  ...    False    False    False  False
# ...      ...                      ...  ...      ...      ...      ...    ...
# 16251   True                     True  ...    False    False    False  False
# 16252  False                    False  ...    False    False    False  False
# 16253    NaN                     True  ...      NaN      NaN      NaN    NaN
# 16254   True                     True  ...    False    False    False  False
# 16255   True                      NaN  ...      NaN      NaN      NaN    NaN
#
#       upscale garage    lot street  valet validated
# 0       False   True  False  False  False     False
# 1       False  False   True  False  False     False
# 2       False   True  False  False  False     False
# 3       False  False  False  False  False     False
# 4       False  False   True  False  False     False
# ...       ...    ...    ...    ...    ...       ...
# 16251   False  False   True   True  False     False
# 16252   False  False   True  False  False     False
# 16253     NaN  False  False   True  False     False
# 16254   False   True  False  False   True     False
# 16255     NaN    NaN    NaN    NaN    NaN       NaN
#
# [16256 rows x 29 columns]

# %%
#store dummy attribute columns in list
atr_dum_df_cols = []

#iterate over object columns
for col in df_attr_conc:
    #if contains a categorical variable then it begins with a u
    try:
        if df_attr_conc[col].str.contains("u'").any():
            #add to the list
            atr_dum_df_cols.append(col)
    except:
        pass

#print out list
print(atr_dum_df_cols)
# Out:
# ['RestaurantsAttire', 'NoiseLevel', 'WiFi', 'Alcohol']

# %%
df_attr_conc['RestaurantsAttire'].unique()
# Out:
# array(["u'casual'", "'casual'", nan, "u'formal'", "u'dressy'", "'dressy'",
#        "'formal'"], dtype=object)

# %%
# Restaurant Attire / formality
restaurant_attire_dict = dict(zip(
    ["u'casual'", "u'dressy'", "u'formal'", 'None',"'casual'","'dressy'","'formal'"],
    ['casual','dressy','formal',np.NaN,'casual','dressy','formal']))

print(restaurant_attire_dict)
# Out:
# {"u'casual'": 'casual', "u'dressy'": 'dressy', "u'formal'": 'formal', 'None': nan, "'casual'": 'casual', "'dressy'": 'dressy', "'formal'": 'formal'}

# %%
#Noise Level
noise_level_dict = dict(zip(
    ["u'average'", np.nan, "'average'", "u'quiet'", "u'loud'", "u'very_loud'",
 "'quiet'", "'very_loud'", "'loud'" ,'None'],
    [2,0,2,1,3,4,1,4,3,0]))

print(noise_level_dict)
# Out:
# {"u'average'": 2, nan: 0, "'average'": 2, "u'quiet'": 1, "u'loud'": 3, "u'very_loud'": 4, "'quiet'": 1, "'very_loud'": 4, "'loud'": 3, 'None': 0}

# %%
#WiFI
wifi_dict = dict(zip(
    ["u'free'", "'free'", "u'no'", "'no'", "u'paid'", "'paid'"],
    ['Free','Free','No','No','Paid', 'Paid']))

print(wifi_dict )
# Out:
# {"u'free'": 'Free', "'free'": 'Free', "u'no'": 'No', "'no'": 'No', "u'paid'": 'Paid', "'paid'": 'Paid'}

# %%
df_attr_conc['Alcohol'].unique()
# Out:
# array(["u'beer_and_wine'", "u'none'", "u'full_bar'", "'none'", nan,
#        "'beer_and_wine'", "'full_bar'"], dtype=object)

# %%
#Alcohol
alcohol_dict = dict(zip(
    ["u'beer_and_wine'", "u'none'", "u'full_bar'",
       "'none'","'beer_and_wine'","'full_bar'"],
    ['beer_and_wine',np.NaN,'full_bar',np.NaN,'beer_and_wine','full_bar']))

print(alcohol_dict)
# Out:
# {"u'beer_and_wine'": 'beer_and_wine', "u'none'": nan, "u'full_bar'": 'full_bar', "'none'": nan, "'beer_and_wine'": 'beer_and_wine', "'full_bar'": 'full_bar'}

# %%
#define mapping for replace method
atr_dict_map = {'RestaurantsAttire': restaurant_attire_dict,
               'NoiseLevel':noise_level_dict,
               'WiFi':wifi_dict,
               'Alcohol':alcohol_dict}

# %%
# get a copy with relevant columns
df_atr_categorical = df_attr[atr_dum_df_cols].copy()


#apply replacement
df_atr_categorical = df_atr_categorical.replace(atr_dict_map)

df_atr_categorical
# Out:
#       RestaurantsAttire  NoiseLevel  WiFi        Alcohol
# 0                casual           2  Free  beer_and_wine
# 1                casual           2  Free            NaN
# 2                casual           2  Free       full_bar
# 3                casual           1   NaN            NaN
# 4                casual           2    No       full_bar
# ...                 ...         ...   ...            ...
# 16251            casual           2  Free  beer_and_wine
# 16252            casual           2    No  beer_and_wine
# 16253            casual           0   NaN       full_bar
# 16254            casual           2    No       full_bar
# 16255               NaN           0   NaN            NaN
#
# [16256 rows x 4 columns]

# %% [markdown]
# ### Impute missing value of Restaurants price range with 0

# %% [markdown]
# df['mix_col'] = pd.to_numeric(
#     df['mix_col'],
#     errors='coerce'
# ).fillna(0).astype('int')

# %%
df_attr_conc['RestaurantsPriceRange2'] = pd.to_numeric(df_attr_conc['RestaurantsPriceRange2'],errors='coerce').fillna(0).astype('int')

# %%
df_attr_conc['RestaurantsPriceRange2'].value_counts()
# Out:
# 2    7206
# 1    6746
# 0    1591
# 3     627
# 4      86
# Name: RestaurantsPriceRange2, dtype: int64

# %%
df_attr_conc['RestaurantsPriceRange2'].replace(0, df_attr_conc['RestaurantsPriceRange2'].median(), inplace=True )

# %%
df_attr_conc
# Out:
#       RestaurantsTakeOut RestaurantsAttire GoodForKids BikeParking  \
# 0                   True         u'casual'        True       False
# 1                   True         u'casual'        True        True
# 2                   True         u'casual'        True       False
# 3                   True          'casual'        True        True
# 4                   True          'casual'        True        True
# ...                  ...               ...         ...         ...
# 16251               True          'casual'        True        True
# 16252               True         u'casual'        True       False
# 16253               True          'casual'       False         NaN
# 16254              False          'casual'       False         NaN
# 16255               True               NaN         NaN         NaN
#
#       OutdoorSeating Caters RestaurantsReservations RestaurantsDelivery  \
# 0              False   True                   False               False
# 1               True   True                   False                True
# 2              False  False                   False               False
# 3               True   True                   False               False
# 4              False    NaN                   False               False
# ...              ...    ...                     ...                 ...
# 16251           True   True                   False                True
# 16252           True  False                   False               False
# 16253          False    NaN                    True               False
# 16254           True  False                    True               False
# 16255            NaN    NaN                     NaN                True
#
#        HasTV RestaurantsGoodForGroups  ... intimate romantic  touristy trendy  \
# 0      False                    False  ...    False    False     False  False
# 1       True                     True  ...    False    False     False  False
# 2       True                    False  ...    False    False      None  False
# 3      False                     True  ...    False    False     False  False
# 4       True                     True  ...    False    False     False  False
# ...      ...                      ...  ...      ...      ...       ...    ...
# 16251   True                     True  ...    False    False     False  False
# 16252  False                    False  ...    False    False     False  False
# 16253    NaN                     True  ...      NaN      NaN       NaN    NaN
# 16254   True                     True  ...    False    False     False  False
# 16255   True                      NaN  ...      NaN      NaN       NaN    NaN
#
#       upscale garage    lot street  valet validated
# 0       False   True  False  False  False     False
# 1       False  False   True  False  False     False
# 2       False   True  False  False  False     False
# 3       False  False  False  False  False     False
# 4       False  False   True  False  False     False
# ...       ...    ...    ...    ...    ...       ...
# 16251   False  False   True   True  False     False
# 16252   False  False   True  False  False     False
# 16253     NaN  False  False   True  False     False
# 16254   False   True  False  False   True     False
# 16255     NaN    NaN    NaN    NaN    NaN       NaN
#
# [16256 rows x 29 columns]

# %%
# drop ['RestaurantsAttire', 'NoiseLevel', 'WiFi', 'Alcohol'] in df_attr_conc
df_attr_conc.drop(columns=['RestaurantsAttire', 'NoiseLevel', 'WiFi', 'Alcohol'],axis=1, inplace = True)

# %%
# combine cleaned attribute as df_attr_cleaned

df_attr_cleaned = pd.concat([df_attr_conc, df_atr_categorical], axis =1)

# %%
#key for reference
df_attr_cleaned['business_id'] = restaurants['business_id']

# %%
df_attr_cleaned.columns
# Out:
# Index(['RestaurantsTakeOut', 'GoodForKids', 'BikeParking', 'OutdoorSeating',
#        'Caters', 'RestaurantsReservations', 'RestaurantsDelivery', 'HasTV',
#        'RestaurantsGoodForGroups', 'BusinessAcceptsCreditCards',
#        'RestaurantsPriceRange2', 'casual', 'classy', 'divey', 'hipster',
#        'intimate', 'romantic', 'touristy', 'trendy', 'upscale', 'garage',
#        'lot', 'street', 'valet', 'validated', 'RestaurantsAttire',
#        'NoiseLevel', 'WiFi', 'Alcohol', 'business_id'],
#       dtype='object')

# %%
restaurants
# Out:
#                   business_id                           name  \
# 0      tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX
# 1      HPA_qyMEddpAEtFof02ixg            Mr G's Pizza & Subs
# 2      jGennaZUr2MsJyRhijNBfA                Legal Sea Foods
# 3      iPD8BBvea6YldQZPHzVrSQ                Espresso Minute
# 4      jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits
# ...                       ...                            ...
# 16251  cgNDiWCaSlqqxx1A6r65bA                     Hop N Cork
# 16252  yQL8SrSETbbCI1U5esVJQw            Ciao! Pizza & Pasta
# 16253  _-nynGfhsMVVWWbAZ6YhTw                  The Jury Room
# 16254  Zl6SUy6x9jqjRu2HbtEO6A           Split Dine and Drink
# 16255  GB75wPibj3IjNauaoCxyGA                    Havana Cafe
#
#                            address         city state postal_code   latitude  \
# 0              7000 NE Airport Way     Portland    OR       97218  45.588906
# 1                    474 Lowell St      Peabody    MA       01960  42.541155
# 2                  1 Harborside Dr       Boston    MA       02128  42.363442
# 3                     334 Mass Ave       Boston    MA       02115  42.342673
# 4               12429 NE Glisan St     Portland    OR       97230  45.526473
# ...                            ...          ...   ...         ...        ...
# 16251  17450 Lower Boones Ferry Rd  Lake Oswego    OR       97035  45.399154
# 16252               59 Williams St      Chelsea    MA       02150  42.389221
# 16253               39 Cottage Ave       Quincy    MA       02269  42.249118
# 16254        7335 SW Bridgeport Rd       Tigard    OR       97224  45.394457
# 16255               910 NW 14th St     Portland    OR       97209  45.529647
#
#         longitude  stars  review_count  is_open  \
# 0     -122.593331    4.0           126        1
# 1      -70.973438    4.0            39        1
# 2      -71.025781    3.5           856        1
# 3      -71.084239    4.5             7        0
# 4     -122.535323    3.5            19        1
# ...           ...    ...           ...      ...
# 16251 -122.737600    4.0           137        1
# 16252  -71.040882    5.0           733        1
# 16253  -71.001071    3.0            30        0
# 16254 -122.752535    2.0            48        0
# 16255 -122.685153    4.0            10        1
#
#                                               attributes          category
# 0      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...  Vegetarian/Vegan
# 1      {'RestaurantsGoodForGroups': 'True', 'HasTV': ...           Western
# 2      {'NoiseLevel': 'u'average'', 'BikeParking': 'F...           Italian
# 3      {'NoiseLevel': ''quiet'', 'GoodForKids': 'True...             Cafes
# 4      {'RestaurantsGoodForGroups': 'True', 'Alcohol'...         Nightlife
# ...                                                  ...               ...
# 16251  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...          American
# 16252  {'GoodForKids': 'True', 'RestaurantsPriceRange...           Italian
# 16253  {'BusinessParking': '{'garage': False, 'street...          American
# 16254  {'RestaurantsDelivery': 'False', 'GoodForKids'...          American
# 16255  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...             Cafes
#
# [16256 rows x 13 columns]

# %%
# Drop 'attributes'
restaurants.drop(columns='attributes',axis=1,inplace=True)

# %% [markdown]
# ## Restaurant Chains

# %% [markdown]
# Conduct additional feature engineering to improve the model.
# Is the business part of a chain.

# %%
restaurants.head()
# Out:
#               business_id                           name              address  \
# 0  tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX  7000 NE Airport Way
# 1  HPA_qyMEddpAEtFof02ixg            Mr G's Pizza & Subs        474 Lowell St
# 2  jGennaZUr2MsJyRhijNBfA                Legal Sea Foods      1 Harborside Dr
# 3  iPD8BBvea6YldQZPHzVrSQ                Espresso Minute         334 Mass Ave
# 4  jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits   12429 NE Glisan St
#
#        city state postal_code   latitude   longitude  stars  review_count  \
# 0  Portland    OR       97218  45.588906 -122.593331    4.0           126
# 1   Peabody    MA       01960  42.541155  -70.973438    4.0            39
# 2    Boston    MA       02128  42.363442  -71.025781    3.5           856
# 3    Boston    MA       02115  42.342673  -71.084239    4.5             7
# 4  Portland    OR       97230  45.526473 -122.535323    3.5            19
#
#    is_open          category
# 0        1  Vegetarian/Vegan
# 1        1           Western
# 2        1           Italian
# 3        0             Cafes
# 4        1         Nightlife

# %%
#get all names that are lower and duplicated
name_lower = restaurants['name'].str.lower().copy()

# %%
name_val_count = name_lower.value_counts(sort=True, ascending=False)

# %%
#see very very popular chains
name_val_count[:30]
# Out:
# subway                           174
# mcdonald's                       138
# dunkin'                           86
# burger king                       70
# domino's pizza                    70
# starbucks                         68
# taco bell                         56
# chipotle mexican grill            55
# wendy's                           46
# papa gino's pizzeria              39
# panera bread                      34
# pizza hut                         33
# papa murphy's                     31
# kfc                               28
# panda express                     26
# five guys                         26
# au bon pain                       24
# 99 restaurants                    22
# b.good                            21
# bertucci's italian restaurant     19
# qdoba mexican eats                19
# jimmy john's                      18
# burgerville                       18
# papa john's pizza                 17
# sweetgreen                        16
# jack in the box                   16
# comella's                         15
# popeyes louisiana kitchen         15
# carl's jr                         15
# upper crust pizzeria              14
# Name: name, dtype: int64

# %%
#see even less popular chains
name_val_count[(name_val_count.values==3)]
# Out:
# petsi pies               3
# chacarero                3
# aquitaine                3
# teriyaki house           3
# jim & patty's coffee     3
#                         ..
# round table clubhouse    3
# cha! cha! cha!           3
# the real deal            3
# the upper crust          3
# brother's roast beef     3
# Name: name, Length: 182, dtype: int64

# %%
# Let chain be restaurants that has at least 5 identical entries

#get chain names
chain_names = name_val_count[(name_val_count.values>=5)].index.tolist()
#see samples
chain_names[:10]
# Out:
# ['subway',
#  "mcdonald's",
#  "dunkin'",
#  'burger king',
#  "domino's pizza",
#  'starbucks',
#  'taco bell',
#  'chipotle mexican grill',
#  "wendy's",
#  "papa gino's pizzeria"]

# %%
def get_chain(bus_name, chain_names=chain_names):
    #convert to string in case not a string
    bus_name_lower = str(bus_name).lower()
    #check if contained in predefied list
    if bus_name_lower in chain_names:
        return 1
    else:
        return 0

# %%
restaurants['chain'] = restaurants['name'].apply(lambda x: get_chain(x, chain_names=chain_names))

# %%
restaurants[restaurants['chain'] == 1]
# Out:
#                   business_id              name  \
# 2      jGennaZUr2MsJyRhijNBfA   Legal Sea Foods
# 5      5PsApTz-WqhF_-8mfqGtGw        Cafe Yumm!
# 7      buTr0hMiyDbjQvFJgm-Eew          JP Licks
# 22     HVpIq8w2SMZK9MQT9u3yng    Gourmet Garden
# 25     FRB3u9Y2boOGDjyQQo7UgA   Regina Pizzeria
# ...                       ...               ...
# 16178  dwLF6jEC5UB8hPa0r93Fxg  Capital One Café
# 16179  ieIMK7tAq9GuqQRzqM-xZA        McDonald's
# 16189  6uuWg3RYUYzrLePphT3PQw       TGI Fridays
# 16207  e8AVhjfCjfu4Hs9yU14O-A            Subway
# 16217  sc7H549jKBNeQwAjD8Vujw    Pizza Schmizza
#
#                                 address        city state postal_code  \
# 2                       1 Harborside Dr      Boston    MA       02128
# 5                    301 SW Morrison St    Portland    OR       97204
# 7                      611 Assembly Row  Somerville    MA       02145
# 22                      139 Endicott St     Danvers    MA       01923
# 25     Arsenal Mall, 485 Arsenal Street   Watertown    MA       02472
# ...                                 ...         ...   ...         ...
# 16178                 425 Revolution Dr  Somerville    MA       02145
# 16179                   180 Endicott St     Danvers    MA       01923
# 16189                   1626 Tremont St      Boston    MA       02120
# 16207               9226 SE Division St    Portland    OR       97266
# 16217         12282 SW Scholls Ferry Rd    Portland    OR       97223
#
#         latitude   longitude  stars  review_count  is_open          category  \
# 2      42.363442  -71.025781    3.5           856        1           Italian
# 5      45.518450 -122.675723    3.5           158        1  Vegetarian/Vegan
# 7      42.395406  -71.079491    3.5           131        1             Cafes
# 22     42.551686  -70.933121    3.5            10        1           Chinese
# 25     42.361382  -71.158536    4.0            10        0           Italian
# ...          ...         ...    ...           ...      ...               ...
# 16178  42.391961  -71.078251    4.5            20        1             Cafes
# 16179  42.547904  -70.941543    2.5            20        1           Western
# 16189  42.333407  -71.104246    2.0           228        1          American
# 16207  45.504123 -122.567525    2.0             5        0         Fast_Food
# 16217  45.443397 -122.803269    2.5             8        0           Western
#
#        chain
# 2          1
# 5          1
# 7          1
# 22         1
# 25         1
# ...      ...
# 16178      1
# 16179      1
# 16189      1
# 16207      1
# 16217      1
#
# [2157 rows x 13 columns]

# %%
#distribution among target value
restaurants.groupby(by='is_open', as_index=True).mean()[['chain']]
# Out:
#             chain
# is_open
# 0        0.080099
# 1        0.167433

# %% [markdown]
# ### Merge the restaurant dataset with df_attr_cleaned

# %%
restaurants_cleaned = restaurants.merge(df_attr_cleaned, on = 'business_id', how='left')

# %%
restaurants_cleaned
# Out:
#                   business_id                           name  \
# 0      tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX
# 1      HPA_qyMEddpAEtFof02ixg            Mr G's Pizza & Subs
# 2      jGennaZUr2MsJyRhijNBfA                Legal Sea Foods
# 3      iPD8BBvea6YldQZPHzVrSQ                Espresso Minute
# 4      jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits
# ...                       ...                            ...
# 16251  cgNDiWCaSlqqxx1A6r65bA                     Hop N Cork
# 16252  yQL8SrSETbbCI1U5esVJQw            Ciao! Pizza & Pasta
# 16253  _-nynGfhsMVVWWbAZ6YhTw                  The Jury Room
# 16254  Zl6SUy6x9jqjRu2HbtEO6A           Split Dine and Drink
# 16255  GB75wPibj3IjNauaoCxyGA                    Havana Cafe
#
#                            address         city state postal_code   latitude  \
# 0              7000 NE Airport Way     Portland    OR       97218  45.588906
# 1                    474 Lowell St      Peabody    MA       01960  42.541155
# 2                  1 Harborside Dr       Boston    MA       02128  42.363442
# 3                     334 Mass Ave       Boston    MA       02115  42.342673
# 4               12429 NE Glisan St     Portland    OR       97230  45.526473
# ...                            ...          ...   ...         ...        ...
# 16251  17450 Lower Boones Ferry Rd  Lake Oswego    OR       97035  45.399154
# 16252               59 Williams St      Chelsea    MA       02150  42.389221
# 16253               39 Cottage Ave       Quincy    MA       02269  42.249118
# 16254        7335 SW Bridgeport Rd       Tigard    OR       97224  45.394457
# 16255               910 NW 14th St     Portland    OR       97209  45.529647
#
#         longitude  stars  review_count  ...  upscale garage    lot street  \
# 0     -122.593331    4.0           126  ...    False   True  False  False
# 1      -70.973438    4.0            39  ...    False  False   True  False
# 2      -71.025781    3.5           856  ...    False   True  False  False
# 3      -71.084239    4.5             7  ...    False  False  False  False
# 4     -122.535323    3.5            19  ...    False  False   True  False
# ...           ...    ...           ...  ...      ...    ...    ...    ...
# 16251 -122.737600    4.0           137  ...    False  False   True   True
# 16252  -71.040882    5.0           733  ...    False  False   True  False
# 16253  -71.001071    3.0            30  ...      NaN  False  False   True
# 16254 -122.752535    2.0            48  ...    False   True  False  False
# 16255 -122.685153    4.0            10  ...      NaN    NaN    NaN    NaN
#
#        valet validated RestaurantsAttire NoiseLevel  WiFi        Alcohol
# 0      False     False            casual          2  Free  beer_and_wine
# 1      False     False            casual          2  Free            NaN
# 2      False     False            casual          2  Free       full_bar
# 3      False     False            casual          1   NaN            NaN
# 4      False     False            casual          2    No       full_bar
# ...      ...       ...               ...        ...   ...            ...
# 16251  False     False            casual          2  Free  beer_and_wine
# 16252  False     False            casual          2    No  beer_and_wine
# 16253  False     False            casual          0   NaN       full_bar
# 16254   True     False            casual          2    No       full_bar
# 16255    NaN       NaN               NaN          0   NaN            NaN
#
# [16256 rows x 42 columns]

# %% [markdown]
# ### Add sentiment score to restaurants datasets

# %%
sentiment_score = pd.read_csv('./data/sentiment_score.csv')

# %%
sentiment_score
# Out:
#                   business_id  sentiment_final
# 0      --6COJIAjkQwSUZci_4PJQ         0.594357
# 1      --UNNdnHRhsyFUbDgumdtQ         0.417455
# 2      -00d-Qb0q2TcWn-8LBHDZg        -0.273694
# 3      -0Gbsd7ztvTyFpl7jF0DIw         0.297091
# 4      -0iqnv7MjKrgh7Q7bYRlUQ        -0.000902
# ...                       ...              ...
# 18088  zyNQhunb1mcSUUbnqVcU1w        -0.148889
# 18089  zyauuvAYdVweBK4L7wBRmw        -0.118130
# 18090  zzO0rjxjVAutcqFnI4VvAg        -0.483112
# 18091  zzcdycb7S42VnnZkwE4yNA        -0.728696
# 18092  zzpmoTVq4yn86U7ArHyFBQ         0.380740
#
# [18093 rows x 2 columns]

# %% [markdown]
# ### Join the sentiment_final score, to restaurants dataframe

# %%
restaurants_cleaned = restaurants_cleaned.merge(sentiment_score, on = 'business_id', how='left')

# %%
restaurants_cleaned
# Out:
#                   business_id                           name  \
# 0      tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX
# 1      HPA_qyMEddpAEtFof02ixg            Mr G's Pizza & Subs
# 2      jGennaZUr2MsJyRhijNBfA                Legal Sea Foods
# 3      iPD8BBvea6YldQZPHzVrSQ                Espresso Minute
# 4      jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits
# ...                       ...                            ...
# 16251  cgNDiWCaSlqqxx1A6r65bA                     Hop N Cork
# 16252  yQL8SrSETbbCI1U5esVJQw            Ciao! Pizza & Pasta
# 16253  _-nynGfhsMVVWWbAZ6YhTw                  The Jury Room
# 16254  Zl6SUy6x9jqjRu2HbtEO6A           Split Dine and Drink
# 16255  GB75wPibj3IjNauaoCxyGA                    Havana Cafe
#
#                            address         city state postal_code   latitude  \
# 0              7000 NE Airport Way     Portland    OR       97218  45.588906
# 1                    474 Lowell St      Peabody    MA       01960  42.541155
# 2                  1 Harborside Dr       Boston    MA       02128  42.363442
# 3                     334 Mass Ave       Boston    MA       02115  42.342673
# 4               12429 NE Glisan St     Portland    OR       97230  45.526473
# ...                            ...          ...   ...         ...        ...
# 16251  17450 Lower Boones Ferry Rd  Lake Oswego    OR       97035  45.399154
# 16252               59 Williams St      Chelsea    MA       02150  42.389221
# 16253               39 Cottage Ave       Quincy    MA       02269  42.249118
# 16254        7335 SW Bridgeport Rd       Tigard    OR       97224  45.394457
# 16255               910 NW 14th St     Portland    OR       97209  45.529647
#
#         longitude  stars  review_count  ...  garage    lot  street  valet  \
# 0     -122.593331    4.0           126  ...    True  False   False  False
# 1      -70.973438    4.0            39  ...   False   True   False  False
# 2      -71.025781    3.5           856  ...    True  False   False  False
# 3      -71.084239    4.5             7  ...   False  False   False  False
# 4     -122.535323    3.5            19  ...   False   True   False  False
# ...           ...    ...           ...  ...     ...    ...     ...    ...
# 16251 -122.737600    4.0           137  ...   False   True    True  False
# 16252  -71.040882    5.0           733  ...   False   True   False  False
# 16253  -71.001071    3.0            30  ...   False  False    True  False
# 16254 -122.752535    2.0            48  ...    True  False   False   True
# 16255 -122.685153    4.0            10  ...     NaN    NaN     NaN    NaN
#
#       validated RestaurantsAttire NoiseLevel  WiFi        Alcohol  \
# 0         False            casual          2  Free  beer_and_wine
# 1         False            casual          2  Free            NaN
# 2         False            casual          2  Free       full_bar
# 3         False            casual          1   NaN            NaN
# 4         False            casual          2    No       full_bar
# ...         ...               ...        ...   ...            ...
# 16251     False            casual          2  Free  beer_and_wine
# 16252     False            casual          2    No  beer_and_wine
# 16253     False            casual          0   NaN       full_bar
# 16254     False            casual          2    No       full_bar
# 16255       NaN               NaN          0   NaN            NaN
#
#       sentiment_final
# 0            0.366400
# 1            0.132592
# 2            0.090394
# 3            0.655234
# 4           -0.114162
# ...               ...
# 16251        0.583473
# 16252        0.676805
# 16253       -0.182383
# 16254       -0.631424
# 16255        0.789037
#
# [16256 rows x 43 columns]

# %%
restaurants_cleaned.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open', 'category',
#        'chain', 'RestaurantsTakeOut', 'GoodForKids', 'BikeParking',
#        'OutdoorSeating', 'Caters', 'RestaurantsReservations',
#        'RestaurantsDelivery', 'HasTV', 'RestaurantsGoodForGroups',
#        'BusinessAcceptsCreditCards', 'RestaurantsPriceRange2', 'casual',
#        'classy', 'divey', 'hipster', 'intimate', 'romantic', 'touristy',
#        'trendy', 'upscale', 'garage', 'lot', 'street', 'valet', 'validated',
#        'RestaurantsAttire', 'NoiseLevel', 'WiFi', 'Alcohol',
#        'sentiment_final'],
#       dtype='object')

# %%
#save the cleaned dataset
restaurants_cleaned.to_pickle('./data/restaurants_cleaned.pkl')

# %% [markdown]
# ## Clean user reviews dataset

# %% [markdown]
# ### Convert date to datetime data type

# %%
# convert 'date' to datetime
user_reviews['date'] = pd.to_datetime(user_reviews['date'], format = '%Y/%m/%d')

# %%
# create year columns
user_reviews['year'] = user_reviews.date.dt.year

# %%
#save the cleaned user reviews dataset
user_reviews.to_pickle('./data/user_reviews_cleaned.pkl')
