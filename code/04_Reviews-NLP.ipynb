# %% [markdown]
# ## Problem Statements

# %% [markdown]
# The F&B space has witnessed massive growth in the past few years. And with the augment of high competition, restaurants owners are striving hard to be ahead of the other competitors.
#
# The goal is to conduct sentimental analysis on customers reviews to identify the factors that contributes to the success of a restaurant. And use classification system to determine whether or not a restaurant will be successful.

# %%
# import libraries
import pandas as pd    
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.dates as mdates
import numpy as np

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import re
from sklearn.metrics import accuracy_score

from datetime import datetime

import pickle

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ## Load data

# %%
user_reviews = pd.read_pickle('./data/portland_reviews.pkl')

# %%
user_reviews.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f246b3b20727> in <module>
# ----> 1 user_reviews.head()
#
# NameError: name 'user_reviews' is not defined

# %%
# reset index
user_reviews = user_reviews.reset_index()

# %%
# Check missing value
user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753055 entries, 0 to 753054
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   index        753055 non-null  int64
#  1   review_id    753055 non-null  object
#  2   user_id      753055 non-null  object
#  3   business_id  753055 non-null  object
#  4   stars        753055 non-null  float64
#  5   useful       753055 non-null  int64
#  6   funny        753055 non-null  int64
#  7   cool         753055 non-null  int64
#  8   text         753055 non-null  object
#  9   date         753055 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 57.5+ MB

# %% [markdown]
# ### Add on data. Sentiment score for state 'MA' & 'OR' excluding Portland

# %% [markdown]
# ### Load data

# %%
user_reviews_state = pd.read_pickle('./data/state_user_reviews.pkl')

# %%
user_reviews_state.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4ba1eadd59f0> in <module>
# ----> 1 user_reviews_state.head()
#
# NameError: name 'user_reviews_state' is not defined

# %%
user_reviews_state.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8632aca6cdb4> in <module>
# ----> 1 user_reviews_state.shape
#
# NameError: name 'user_reviews_state' is not defined

# %%
# reset index
user_reviews_state = user_reviews_state.reset_index()

# %%
# Check missing value
user_reviews_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1529250 entries, 0 to 1529249
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   index        1529250 non-null  int64
#  1   review_id    1529250 non-null  object
#  2   user_id      1529250 non-null  object
#  3   business_id  1529250 non-null  object
#  4   stars        1529250 non-null  float64
#  5   useful       1529250 non-null  int64
#  6   funny        1529250 non-null  int64
#  7   cool         1529250 non-null  int64
#  8   text         1529250 non-null  object
#  9   date         1529250 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 116.7+ MB

# %% [markdown]
# ## Preprocessing text

# %% [markdown]
# 1. Removing punctuations
# 2. Lower casing
# 3. Removing stopword
# 4. Tokenization
# 5. Lemmatization

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
# Declare functions for preprocessing
def preprocessing(text):
    punctuationfree= "".join([i for i in text if i not in string.punctuation]) ## remove punctuation
    sentence = punctuationfree.lower() #convert uppercase to lowercase
    nostopword = " ".join([word for word in sentence.split() if word not in (stopwords)])
    tokenizer = RegexpTokenizer(r'[a-zA-Z0-9]+') # extract the sentence that contain alphabat and numbers only.
    tokens = tokenizer.tokenize(nostopword) #tokenize the word
    lemma_words=[lemmatizer.lemmatize(w) for w in tokens]
    new_text = ' '.join(lemma_words) #rejoin the sentence
    return nostopword

# %%
user_reviews['clean_msg']= user_reviews['text'].apply(lambda x:preprocessing(x))
user_reviews.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-87c5f8145490> in <module>
# ----> 1 user_reviews['clean_msg']= user_reviews['text'].apply(lambda x:preprocessing(x))
#       2 user_reviews.head()
#
# NameError: name 'user_reviews' is not defined

# %%
# %%time
user_reviews_state['clean_msg']= user_reviews_state['text'].apply(lambda x:preprocessing(x))
user_reviews_state.head()
# Out:
# Wall time: 9min 33s
#    index               review_id                 user_id  \
# 0      0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw
# 1      5  J4a2TuhDasjn2k3wWtHZnQ  RNm_RWkcd02Li2mKPRe7Eg
# 2      6  28gGfkLs3igtjVy61lh77Q  Q8c91v7luItVB0cMFF_mRA
# 3      9  KKVFopqzcVfcubIBxmIjVA  99RsBrARhhx60UnAC4yDoA
# 4     18  btNWW2kdJYfwpTDyzJO3Iw  DECuRZwkUw8ELQZfNGef2Q
#
#               business_id  stars  useful  funny  cool  \
# 0  buF9druCkbuXLX526sGELQ    4.0       3      1     1
# 1  xGXzsc-hzam-VArK6eTvtw    1.0       2      0     0
# 2  EXOsmAB1s71WePlQk0WZrA    2.0       0      0     0
# 3  EEHhKSxUvJkoPSzeGKkpVg    5.0       0      0     0
# 4  zmZ3HkVCeZPBefJJxzdJ7A    4.0       0      0     0
#
#                                                 text                 date  \
# 0  Apparently Prides Osteria had a rough summer a...  2014-10-11 03:34:02
# 1  This place used to be a cool, chill place. Now...  2018-01-21 04:41:03
# 2  The setting is perfectly adequate, and the foo...  2006-04-16 02:58:44
# 3  I work in the Pru and this is the most afforda...  2014-05-07 18:10:21
# 4  Nothing special but good enough.  I like anoth...  2012-12-04 04:29:47
#
#                                            clean_msg
# 0  apparently prides osteria rough summer evidenc...
# 1  place used cool chill place bunch neanderthal ...
# 2  setting perfectly adequate food comes close di...
# 3  work pru affordable tasty place food court dea...
# 4  nothing special good enough like another one m...

# %%
# Calculate numbers of words
user_reviews['words'] = [len(x.split()) for x in user_reviews['clean_msg'].tolist()]

# %%
# Calculate numbers of words
user_reviews_state['words'] = [len(x.split()) for x in user_reviews_state['clean_msg'].tolist()]

# %%
# drop rows where words count more than 512 so that no-error for running sentiment analysis models from hugging face.
#user_reviews.drop( user_reviews[ user_reviews['words'] >= 512].index , inplace=True)

# %%
user_reviews = user_reviews.reset_index()

# %%
user_reviews_state = user_reviews_state.reset_index()

# %%
user_reviews.shape
# Out:
# (753055, 12)

# %%
user_reviews_state.shape
# Out:
# (1529250, 13)

# %% [markdown]
# ### Sentiment Analysis using hugging face

# %%
#!pip install --upgrade tensorflow
#!pip install transformers

# %%
from transformers import pipeline

# %%
sentiment = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
user_reviews['sentiment_dict'] = user_reviews['clean_msg'].apply(lambda review: sentiment(review, truncation=True))

user_reviews
# Out:
#           index               review_id                 user_id  \
# 0            35  nJTSr-EGNhhA5o146THkPg  T9O5pkKKlNvr-qqfefDlbA
# 1            42  lJ7rzbvT-l8KO8lHfEsXsg  LV1ME-ibA2h0IGyFUUWhaQ
# 2            45  m-9DK7NwYedIPj1RQ_sXdw  JuM-lH05m6Ln8OPUTg8p0g
# 3            49  EO5rALvJMkK8QEvUNs1gxg  u2xPfv6_wcKt-lW-C1cV8A
# 4            67  OH9E5SaGBQsPX3IktM30mg  7mWnNVk2n99JxkvV3PW0nA
# ...         ...                     ...                     ...
# 753050  8635355  CCv8DP1zZyoI0FvgEdeTgg  7pGvyqTBe5vcmKG29Gcz3Q
# 753051  8635371  pevp4H0U6Q7UKl-J9PBLLQ  yDeqOLo8pp1xpzHWBKFEfA
# 753052  8635391  XpVatkv32ZiY3Mv_cR26Mw  UvlvbgQaADuIoE2bEQYJ1A
# 753053  8635397  FfhmA0G0zrRjHskp-7O8UQ  IlxM3NGJOtNXPz5cupqNDQ
# 753054  8635400  7vNXRIClt-9rFzMXlrtMXA  tr13Jb83h2itjyXVwaO5eA
#
#                    business_id  stars  useful  funny  cool  \
# 0       luOZQ9YBrWwP8mYrS4rNoA    4.0       2      0     0
# 1       H_RM2u1WWGU1HkKZrYq2Ow    5.0       0      0     0
# 2       H_RM2u1WWGU1HkKZrYq2Ow    5.0       0      0     0
# 3       9P-lp3AWDXGayDqJz9VPwQ    2.0       0      0     0
# 4       Un6u2cECyV4nZb_HGZ-uTA    4.0       1      0     1
# ...                        ...    ...     ...    ...   ...
# 753050  d69y3CN9_SQKrEnXXqQr8g    5.0       1      0     0
# 753051  2JKien1H998FluEYs0xIrg    5.0       3      0     1
# 753052  _VF1CWhsQWv77Yi92ORo1w    5.0       0      0     0
# 753053  dmkDZKPsK8lmwFuLiFQ0Zw    5.0       0      0     0
# 753054  rbuj2X4SXIc3MDul4dcxIA    5.0      39     13    34
#
#                                                      text                date  \
# 0       This place has some of the BEST chinese take-o... 2008-12-03 04:39:26
# 1       Incredible donuts. Sometimes you have to go ea... 2017-08-07 19:34:13
# 2       Dont bother going to voodoo, just come here in... 2016-09-18 17:06:01
# 3       The ramen here is less than great. It came out... 2018-02-11 03:30:12
# 4       It's crazy how establishments on the west coas... 2011-02-13 16:38:09
# ...                                                   ...                 ...
# 753050  King burrito is my go to Burritos when I'm nea... 2020-10-05 18:30:46
# 753051  Where do I start with Buranko? Everything I tr... 2020-12-06 23:19:24
# 753052  Wonderful! We stopped in twice while taking ou... 2021-01-20 20:07:19
# 753053  Yes please! We had the Arepas falafel style an... 2021-01-25 14:53:13
# 753054  Yummy, great chew on the bagel\nFriendly staff... 2020-06-13 02:39:26
#
#                                                 clean_msg  words  \
# 0       place best chinese takeout portland dont let i...     49
# 1       incredible donuts sometimes go early full sele...     10
# 2       dont bother going voodoo come instead unique f...     14
# 3       ramen less great came luke warm oily service r...     11
# 4       crazy establishments west coast many yelp revi...    101
# ...                                                   ...    ...
# 753050  king burrito go burritos im near enough area b...     79
# 753051  start buranko everything tried matcha cocktail...     18
# 753052  wonderful stopped twice taking son bacon nonba...     60
# 753053  yes please arepas falafel style maccurles fres...     15
# 753054  yummy great chew bagel friendly staff clean es...     11
#
#                                            sentiment_dict
# 0       [{'label': 'POSITIVE', 'score': 0.997427761554...
# 1       [{'label': 'POSITIVE', 'score': 0.999814927577...
# 2       [{'label': 'NEGATIVE', 'score': 0.877250492572...
# 3       [{'label': 'POSITIVE', 'score': 0.629967510700...
# 4       [{'label': 'POSITIVE', 'score': 0.958464384078...
# ...                                                   ...
# 753050  [{'label': 'POSITIVE', 'score': 0.995506882667...
# 753051  [{'label': 'NEGATIVE', 'score': 0.976583719253...
# 753052  [{'label': 'POSITIVE', 'score': 0.994185268878...
# 753053  [{'label': 'POSITIVE', 'score': 0.999734461307...
# 753054  [{'label': 'POSITIVE', 'score': 0.999188601970...
#
# [753055 rows x 13 columns]

# %%
# Split MA and OR user reviews into 6 parts to pass into huggingface transformer separately.
x = np.array_split(user_reviews_state, 6)

# %%
user_reviews_state_b1 = x[0]

user_reviews_state_b2 = x[1]

user_reviews_state_b3 = x[2]


user_reviews_state_b4 = x[3]

user_reviews_state_b5 = x[4]

user_reviews_state_b6 = x[5]

# %%
# %%time
user_reviews_state_b1['sentiment_dict'] = user_reviews_state_b1['clean_msg'].apply(lambda review: sentiment(review, truncation=True))
user_reviews_state_b1
# Out:
# Wall time: 7h 25min 29s
#         level_0    index               review_id                 user_id  \
# 0             0        0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw
# 1             1        5  J4a2TuhDasjn2k3wWtHZnQ  RNm_RWkcd02Li2mKPRe7Eg
# 2             2        6  28gGfkLs3igtjVy61lh77Q  Q8c91v7luItVB0cMFF_mRA
# 3             3        9  KKVFopqzcVfcubIBxmIjVA  99RsBrARhhx60UnAC4yDoA
# 4             4       18  btNWW2kdJYfwpTDyzJO3Iw  DECuRZwkUw8ELQZfNGef2Q
# ...         ...      ...                     ...                     ...
# 254870   254870  1365416  dSjc_GhOmeyXTZp_AuY7ow  wWjhYtHyA_q4EI692RT16A
# 254871   254871  1365421  hCeBIEV8-55ptdp9spfzzA  k-SEvnJluFQjAsaGSgE9Sg
# 254872   254872  1365432  Qg2G4RgisZ7as-rm7Zd9ow  ld5H3Nf3xhUuvybL1uMFng
# 254873   254873  1365434  cirIXjD3m8hBo8ULygVKGQ  c3uVgOugNz-7IrAZHEIFsg
# 254874   254874  1365438  16dsg_KD0xW4wL6tE9T85A  wfRywf8J4XXYYFbNpa43Xw
#
#                    business_id  stars  useful  funny  cool  \
# 0       buF9druCkbuXLX526sGELQ    4.0       3      1     1
# 1       xGXzsc-hzam-VArK6eTvtw    1.0       2      0     0
# 2       EXOsmAB1s71WePlQk0WZrA    2.0       0      0     0
# 3       EEHhKSxUvJkoPSzeGKkpVg    5.0       0      0     0
# 4       zmZ3HkVCeZPBefJJxzdJ7A    4.0       0      0     0
# ...                        ...    ...     ...    ...   ...
# 254870  EmZep9cupsMffqCAvjr5fg    4.0       0      0     1
# 254871  c67rQbz3CEXyI0nd5kG-Uw    3.0       0      0     1
# 254872  -hdRA7xgZPnDozuYhkFycg    1.0       1      0     0
# 254873  06feX4qEHFMcPZsiWtvYfw    4.0       0      0     0
# 254874  CCG8oASUxEXjpXfThE6D4w    4.0       0      0     0
#
#                                                      text  \
# 0       Apparently Prides Osteria had a rough summer a...
# 1       This place used to be a cool, chill place. Now...
# 2       The setting is perfectly adequate, and the foo...
# 3       I work in the Pru and this is the most afforda...
# 4       Nothing special but good enough.  I like anoth...
# ...                                                   ...
# 254870  Healthy fast food? What a concept. I'm a huge ...
# 254871  Ahh, Starbucks' rival situated right across th...
# 254872  Go here if you (or your kids) have a hankering...
# 254873  Excellent coffee. I have had their Iced Coffee...
# 254874  Hush puppies.\nSide salads.\nLamb burger to sp...
#
#                        date  \
# 0       2014-10-11 03:34:02
# 1       2018-01-21 04:41:03
# 2       2006-04-16 02:58:44
# 3       2014-05-07 18:10:21
# 4       2012-12-04 04:29:47
# ...                     ...
# 254870  2007-10-18 00:48:29
# 254871  2010-01-05 09:41:21
# 254872  2018-01-19 22:08:01
# 254873  2016-06-05 20:01:28
# 254874  2012-06-25 14:52:27
#
#                                                 clean_msg  words  \
# 0       apparently prides osteria rough summer evidenc...    174
# 1       place used cool chill place bunch neanderthal ...     27
# 2       setting perfectly adequate food comes close di...     20
# 3       work pru affordable tasty place food court dea...     32
# 4       nothing special good enough like another one m...     17
# ...                                                   ...    ...
# 254870  healthy fast food concept im huge fan veggie b...     24
# 254871  ahh starbucks rival situated right across stre...     81
# 254872  go kids hankering games otherwise worst possib...     39
# 254873  excellent coffee iced coffee cold brew previou...     34
# 254874  hush puppies side salads lamb burger split hus...     58
#
#                                            sentiment_dict
# 0       [{'label': 'POSITIVE', 'score': 0.941629588603...
# 1       [{'label': 'NEGATIVE', 'score': 0.998412013053...
# 2       [{'label': 'POSITIVE', 'score': 0.975937008857...
# 3       [{'label': 'POSITIVE', 'score': 0.992754995822...
# 4       [{'label': 'NEGATIVE', 'score': 0.998852014541...
# ...                                                   ...
# 254870  [{'label': 'POSITIVE', 'score': 0.999549329280...
# 254871  [{'label': 'NEGATIVE', 'score': 0.984495878219...
# 254872  [{'label': 'NEGATIVE', 'score': 0.999691128730...
# 254873  [{'label': 'POSITIVE', 'score': 0.997478663921...
# 254874  [{'label': 'POSITIVE', 'score': 0.989620804786...
#
# [254875 rows x 14 columns]

# %%
user_reviews_state_b1.to_pickle('./data/user_reviews_state_b1.pkl')

# %%
# %%time
user_reviews_state_b2['sentiment_dict'] = user_reviews_state_b2['clean_msg'].apply(lambda review: sentiment(review, truncation=True))
user_reviews_state_b2
# Out:
# Wall time: 7h 26min 44s
#         level_0    index               review_id                 user_id  \
# 254875   254875  1365439  vXXDRPPe_DWXpchRrtzULg  OsZ_5G7zbXycL6Evf0ElBA
# 254876   254876  1365441  BfE_9K_kiG02L4U_K2r1CQ  QzTXHL2oFRghfKLabzkXzA
# 254877   254877  1365447  wgLyWOkV1xFnE-pFp9_rQg  eEKPzAEdgeEoy19o0Yq4Ng
# 254878   254878  1365448  VLa5AGGtCJI5pWUVPjt9cA  kMpSSx0VEiLFiA18sGbEpQ
# 254879   254879  1365451  asxCQ4KCe12qu0XT7mtwXA  NJOspTE_Ms-b8ACPKY73Ww
# ...         ...      ...                     ...                     ...
# 509745   509745  2841025  TqjIKMZghsihYuDjLZMRvA  ZM6XDLkChp6X_jYylpEjZQ
# 509746   509746  2841026  xpNAQCfx-35eAfu65DqrQA  kUdX6itbIh0Fjh41UXgxiQ
# 509747   509747  2841028  wWvXHveDv1JpyP6k3lwhcQ  4QWiI4dWxxd2wU6vEeTiSA
# 509748   509748  2841029  HgVM_QB-3xTbS_edJYJ4Fw  UytHAPnIKow1gmab3NfGzg
# 509749   509749  2841030  e0--7LoQKYnlDPh2bNuUmQ  OCc6Cdlv1kc40wVdWjL2ZQ
#
#                    business_id  stars  useful  funny  cool  \
# 254875  TvR5gt1ZiPx5Hnouz_i0pA    4.0       0      0     0
# 254876  VnuD2cojPTWd3nIHQjnL8w    5.0       1      0     0
# 254877  yNYyM-xdZDh_rITFDMp2tg    2.0       0      0     0
# 254878  tfdIB3AlviYKVYguaT1S8g    5.0       2      0     2
# 254879  WYnXpXym2DMtwchDcbilmg    4.0       2      1     2
# ...                        ...    ...     ...    ...   ...
# 509745  3kUWjyRGWc_RUGDw9X3qUw    4.0       1      0     0
# 509746  kt2mUzQEBX5oYngareeyQA    5.0       1      0     0
# 509747  Tbq4hgX7uUzgFUWDlmqnBw    3.0       0      0     0
# 509748  dbljEYM1md67eqYbK2LHNA    4.0       0      1     0
# 509749  2p8xEv2te5XUPhy7TLellg    5.0       0      0     0
#
#                                                      text  \
# 254875  Two words: Nutella. Latte. Even if you're not ...
# 254876  I was in Boston for a week on business, and I ...
# 254877  Went there for All-you-can-eat dinner on Sunda...
# 254878  Just came here tonight after they opened yeste...
# 254879  Great dough means great Pizza\n\nFor whatever ...
# ...                                                   ...
# 509745  its great food in cleveland circle.  the break...
# 509746  I went out with my high school friends and the...
# 509747  So, not like this affected my opinion of this ...
# 509748  For those not in the know of the North Shore, ...
# 509749  Fantastic Italian food...Great bar..Had the tw...
#
#                        date  \
# 254875  2018-01-09 01:19:43
# 254876  2011-06-25 18:53:58
# 254877  2016-10-12 20:53:24
# 254878  2009-09-27 00:41:54
# 254879  2018-01-30 19:23:49
# ...                     ...
# 509745  2013-08-23 17:53:48
# 509746  2017-10-29 22:42:11
# 509747  2011-03-30 00:03:45
# 509748  2015-12-29 23:04:57
# 509749  2013-07-26 16:13:56
#
#                                                 clean_msg  words  \
# 254875  two words nutella latte even youre particularl...     98
# 254876  boston week business excited would opportunity...    129
# 254877  went allyoucaneat dinner sunday friend didnt w...    133
# 254878  came tonight opened yesterday say wow half doz...    236
# 254879  great dough means great pizza whatever reason ...     93
# ...                                                   ...    ...
# 509745  great food cleveland circle breakfast sandwich...     45
# 509746  went high school friends wives last night rose...     32
# 509747  like affected opinion place found boston doesn...     62
# 509748  know north shore say imo chinese restaurant ot...    169
# 509749  fantastic italian foodgreat barhad twin pork c...     15
#
#                                            sentiment_dict
# 254875  [{'label': 'POSITIVE', 'score': 0.989696919918...
# 254876  [{'label': 'POSITIVE', 'score': 0.980813443660...
# 254877  [{'label': 'NEGATIVE', 'score': 0.995622098445...
# 254878  [{'label': 'NEGATIVE', 'score': 0.994411051273...
# 254879  [{'label': 'POSITIVE', 'score': 0.972228586673...
# ...                                                   ...
# 509745  [{'label': 'POSITIVE', 'score': 0.998139023780...
# 509746  [{'label': 'POSITIVE', 'score': 0.999428212642...
# 509747  [{'label': 'NEGATIVE', 'score': 0.981866538524...
# 509748  [{'label': 'POSITIVE', 'score': 0.951515376567...
# 509749  [{'label': 'POSITIVE', 'score': 0.997601091861...
#
# [254875 rows x 14 columns]

# %%
user_reviews_state_b2.to_pickle('./data/user_reviews_state_b2.pkl')

# %%
# %%time
user_reviews_state_b3['sentiment_dict'] = user_reviews_state_b3['clean_msg'].apply(lambda review: sentiment(review, truncation=True))
user_reviews_state_b3
# Out:
# Wall time: 6h 58min 14s
#         level_0    index               review_id                 user_id  \
# 509750   509750  2841047  tSGXfr7IeeooBtx1na8fBg  qqhx6Z0PGTs1Z6JxxyKD6Q
# 509751   509751  2841050  01qIQR_UJGvBb-nyxAtgiQ  QVT7iO4asnO4iv2kCYFzaQ
# 509752   509752  2841061  LD57M-CFpSg-IwolAVAsdA  IKpOC19QI_I96vdJhrMEaA
# 509753   509753  2841068  rUH0kkGHcmpPyIBe6JBIeg  Y7ihQ8cVQTxO4LTYVuyd2Q
# 509754   509754  2841069  AlKvgIw-xhGc-5vHzVbnqQ  UCiPaQcM_UgCMbJqtrVduQ
# ...         ...      ...                     ...                     ...
# 764620   764620  4383303  GANvZNlQnBcNYcnhm6m3aA  5dZ_waKhnA3VKAjoauasfw
# 764621   764621  4383306  1FXODyjS4KaX6F44y0eL9Q  GMough92VMnVOqIDau0DTw
# 764622   764622  4383307  o8fYNhBoVrePyi_RxzgJUw  EmJWWbJiqOU6N2vpO1-v6Q
# 764623   764623  4383313  03aDdj-oi4NtPj0OJgYhow  0EFQQB40D24-WuIFH6-rpQ
# 764624   764624  4383316  AtpXvegtqoe-VyJ_oJOHCw  gqoXOTISm9-f7ohQtTqruA
#
#                    business_id  stars  useful  funny  cool  \
# 509750  UAPC8w0gfnay_2bjo6Oxlw    5.0       0      0     0
# 509751  3DjBQEw27_cMm_0H5I93CQ    3.0       2      1     0
# 509752  TJ2TqRQPi4V-QqVSyG8fcA    3.0       3      3     4
# 509753  63DvXSks1tHIDajOGvwnRQ    4.0       3      2     4
# 509754  mtG5TI0nPbrty2zf8Gz7Jg    3.0       0      0     0
# ...                        ...    ...     ...    ...   ...
# 764620  WeAMq_YGgAnuayjJHi8gQg    5.0       1      0     0
# 764621  E595x5S7SkVXePXRb1zfeg    5.0       0      0     0
# 764622  dmLrPLWGLGkI3qBixFDEvw    4.0       0      0     0
# 764623  bt25E3D09r6rNSwUwYr1pw    3.0       1      1     1
# 764624  sBmqZaRVgj5HBeeCILu6yQ    5.0       0      0     0
#
#                                                      text  \
# 509750  Delicious, delicious, delicious!  Stop thinkin...
# 509751  I've been here for breakfast a few times and h...
# 509752  If it's a cold winter day, or you're just look...
# 509753  This place has good dessert. I have been comin...
# 509754  this place is right next to my office, and see...
# ...                                                   ...
# 764620  This place is amazing!! Earth Wind and Fire sa...
# 764621  Practically ate my fingers off! So delicious a...
# 764622  For their food, this is my favourite bakery in...
# 764623  One of the first things I want to find to be c...
# 764624  Tom E's is a local dive bar that has cheap bee...
#
#                        date  \
# 509750  2012-12-17 17:16:50
# 509751  2015-02-23 14:16:59
# 509752  2014-07-21 15:33:59
# 509753  2011-09-05 22:22:31
# 509754  2014-08-18 20:50:37
# ...                     ...
# 764620  2018-05-20 13:37:20
# 764621  2016-04-25 00:37:39
# 764622  2013-10-27 02:29:02
# 764623  2007-06-17 01:25:15
# 764624  2016-08-14 15:29:00
#
#                                                 clean_msg  words  \
# 509750  delicious delicious delicious stop thinking ea...     16
# 509751  ive breakfast times generally good experience ...     84
# 509752  cold winter day youre looking betterthanramen ...     99
# 509753  place good dessert coming years never disappoi...     70
# 509754  place right next office seemed like good spot ...     46
# ...                                                   ...    ...
# 764620  place amazing earth wind fire sandwich incredi...     25
# 764621  practically ate fingers delicious flavorful ne...     52
# 764622  food favourite bakery chinatown make best pork...    113
# 764623  one first things want find comfortable new tow...     96
# 764624  tom es local dive bar cheap beers pool tablesd...     24
#
#                                            sentiment_dict
# 509750  [{'label': 'POSITIVE', 'score': 0.999845743179...
# 509751  [{'label': 'NEGATIVE', 'score': 0.993640840053...
# 509752  [{'label': 'POSITIVE', 'score': 0.967772424221...
# 509753  [{'label': 'POSITIVE', 'score': 0.993344426155...
# 509754  [{'label': 'NEGATIVE', 'score': 0.980192840099...
# ...                                                   ...
# 764620  [{'label': 'POSITIVE', 'score': 0.999782741069...
# 764621  [{'label': 'POSITIVE', 'score': 0.998603403568...
# 764622  [{'label': 'NEGATIVE', 'score': 0.995082020759...
# 764623  [{'label': 'NEGATIVE', 'score': 0.873414993286...
# 764624  [{'label': 'POSITIVE', 'score': 0.865505278110...
#
# [254875 rows x 14 columns]

# %%
user_reviews_state_b3.to_pickle('./data/user_reviews_state_b3.pkl')

# %%
# %%time
user_reviews_state_b4['sentiment_dict'] = user_reviews_state_b4['clean_msg'].apply(lambda review: sentiment(review, truncation=True))
user_reviews_state_b4
# Out:
# Wall time: 7h 9min 4s
#          level_0    index               review_id                 user_id  \
# 764625    764625  4383319  65nvHVPpLa5__iGasT2umA  faE9EeR2Ju5gC4LbvL13UQ
# 764626    764626  4383327  5idTgJPdpLayFwUZy7z2PQ  Ow0U1QnwvrQK0Wcig5fWkg
# 764627    764627  4383328  MAaEO8yWYkp8QgpZHhnMqA  u6WOVeQaV-Psk2lO_5sVMA
# 764628    764628  4383329  5BUGffUjkc5wX85cWYOAYA  bpC9Gt5fcN_1OjDEgjuvpw
# 764629    764629  4383331  I-buQfYH7H5h4EYUQAazEw  89yr7wNIk8TE03yKfTRLuQ
# ...          ...      ...                     ...                     ...
# 1019495  1019495  5712377  EqcwHtdg2Dt1821c7QUunQ  gfQqQYI5_hCAGEHlHXIz2Q
# 1019496  1019496  5712382  5uWdsQhVmNjHr8uAW4_MTg  8NQfyo7Q4fkI8wvJ_VjKPg
# 1019497  1019497  5712386  CJnYnhXBf-jvD8nmEDgU6Q  raDxhVz-c1sjlKNc3Mitiw
# 1019498  1019498  5712388  goPtIHfQleZt7xzj1KKwmw  3Bv-fauoFlnSkcydjUnInQ
# 1019499  1019499  5712396  ITyFDfsb9wBcod937CMSkA  rWsKk7VlxIfil4YznihAgw
#
#                     business_id  stars  useful  funny  cool  \
# 764625   j_fhXdgayrGKD1xTr2bJJQ    4.0       1      0     0
# 764626   4gclbVl9p3st4vjBTTNN4Q    5.0       0      0     0
# 764627   3hW1nSUX8BsNSJGxGqcZCw    4.0       0      1     0
# 764628   pXXrBOdooMzg12bW57xWDw    1.0       2      0     0
# 764629   SspVW7z1OvbojeFs6InjJA    4.0       3      0     1
# ...                         ...    ...     ...    ...   ...
# 1019495  hzSyQBWeoX94WOpUtxuWVg    3.0       3      0     2
# 1019496  6SMj1FNYRUxINR1smZMcrw    4.0       0      0     0
# 1019497  TR5H53J3ASZAswpDxgEMtg    5.0       3      2     2
# 1019498  bOsi1qC5rkfZ5-JKuP38Bg    1.0       3      0     0
# 1019499  yBIN7uSzd5saehWA1I_GBw    5.0       2      0     1
#
#                                                       text  \
# 764625   It's a small cozy place with exotic decor and ...
# 764626   I was in the mood for something quick so I sto...
# 764627   good. fresh. great service. good prices. prett...
# 764628   I was craving a Five Guys hot dog and went her...
# 764629   Save this restaurant, please!\n\nOn a recent F...
# ...                                                    ...
# 1019495  After many failed attempts, we finally made it...
# 1019496  It was a beautiful day for a picnic in the par...
# 1019497  Good burritos, nice atmosphere. We sat there f...
# 1019498  Food was very bad. Mussels tasted very off (as...
# 1019499  There's a definite reason why this place has a...
#
#                         date  \
# 764625   2012-10-11 20:18:28
# 764626   2009-10-25 18:12:29
# 764627   2014-02-27 01:09:45
# 764628   2013-06-25 15:15:51
# 764629   2008-05-10 23:42:39
# ...                      ...
# 1019495  2008-07-24 13:44:15
# 1019496  2009-05-07 17:04:15
# 1019497  2014-07-24 16:29:00
# 1019498  2016-08-25 02:15:04
# 1019499  2016-05-04 01:43:10
#
#                                                  clean_msg  words  \
# 764625   small cozy place exotic decor tasty food tried...     23
# 764626   mood something quick stopped new pats trattori...     66
# 764627   good fresh great service good prices pretty am...     13
# 764628   craving five guys hot dog went really sloppy b...     44
# 764629   save restaurant please recent friday night tw ...    174
# ...                                                    ...    ...
# 1019495  many failed attempts finally made cottage orde...     59
# 1019496  beautiful day picnic parkso decided give strip...     50
# 1019497  good burritos nice atmosphere sat chatting own...     13
# 1019498  food bad mussels tasted bad items felt like ma...     28
# 1019499  theres definite reason place near perfect rati...    111
#
#                                             sentiment_dict
# 764625   [{'label': 'POSITIVE', 'score': 0.995652914047...
# 764626   [{'label': 'POSITIVE', 'score': 0.997915804386...
# 764627   [{'label': 'POSITIVE', 'score': 0.999777019023...
# 764628   [{'label': 'NEGATIVE', 'score': 0.989550054073...
# 764629   [{'label': 'NEGATIVE', 'score': 0.569564104080...
# ...                                                    ...
# 1019495  [{'label': 'NEGATIVE', 'score': 0.992341160774...
# 1019496  [{'label': 'POSITIVE', 'score': 0.998371183872...
# 1019497  [{'label': 'POSITIVE', 'score': 0.998202204704...
# 1019498  [{'label': 'NEGATIVE', 'score': 0.999747574329...
# 1019499  [{'label': 'POSITIVE', 'score': 0.991563081741...
#
# [254875 rows x 14 columns]

# %%
user_reviews_state_b4.to_pickle('./data/user_reviews_state_b4.pkl')

# %%
# %%time
user_reviews_state_b5['sentiment_dict'] = user_reviews_state_b5['clean_msg'].apply(lambda review: sentiment(review, truncation=True))
user_reviews_state_b5
# Out:
# Wall time: 7h 17min 17s
#          level_0    index               review_id                 user_id  \
# 1019500  1019500  5712400  WExK1XiQIQBTwXKkm0vs7A  -aOZfLtxyWvc8ywDS7AIKQ
# 1019501  1019501  5712414  Im3YZ7c338buIh8BUafX_A  8GFaImY3Z4h83uP8JjWiBQ
# 1019502  1019502  5712417  UqVOAIAqpRrZaGjcxLzPlA  UAvHIpbXzQqJAXePDTJkZw
# 1019503  1019503  5712419  mD0zoCYxiIW5BBtMxmH7og  U2HffzKY5zOxEWrAhNijZQ
# 1019504  1019504  5712420  sh57JUNzNlsWBR_uNotUMA  _f2gLN3JSI-WYpgakE66aw
# ...          ...      ...                     ...                     ...
# 1274370  1274370  7209211  biswCr00Fog-w31YfYOX7g  QdESTLJtOtjEL3LvRwzUPQ
# 1274371  1274371  7209214  vDi4k3Sw8x0TxF-cBtWCNA  B13luJQsN3P0yIR93DBxbg
# 1274372  1274372  7209215  jerpldZeJC_KvoioThtJIA  Ha12xaINJ0-aEbjnLoAAyQ
# 1274373  1274373  7209232  NaoNuWI9OhwpTNgBuYhLsA  nIg5Gb-mpG3NS9n2zi5d9A
# 1274374  1274374  7209233  5Nbgl4rZCaZr2DfaxAkGDQ  YFRNtXu6lk0fNZkecJlYLA
#
#                     business_id  stars  useful  funny  cool  \
# 1019500  kEu0XqDrQNbzkBF8BZta3w    4.0       0      0     0
# 1019501  89vuE7Q_TiEjsBbrznoFlA    2.0       0      0     0
# 1019502  s9c3ufuhJ3phG1XI0zey0Q    4.0       1      0     0
# 1019503  58cDJU4cub1o0o0B4h9GrA    4.0       0      0     0
# 1019504  DuT5BBmKRtcGYQzKkoEiZw    2.0       0      0     0
# ...                         ...    ...     ...    ...   ...
# 1274370  CkuBBI7ROUFNNF8mSQl8tQ    4.0       1      1     1
# 1274371  9RH1xBIMMAZXg9s_XW_sLg    5.0       0      0     0
# 1274372  WH7YE7GN_7nKcpuoHh03eA    5.0       1      1     0
# 1274373  MgmTEMoY2RgZS1Q02HacGQ    4.0       0      0     0
# 1274374  fnH2j1K_M6pxuuYPF3S2Zw    3.0       1      1     1
#
#                                                       text  \
# 1019500  My friend and I swung by Sibling Rivalry just ...
# 1019501  boy, what an average, expensive meal.  $30 for...
# 1019502  Excellent place to grab breakfast! It was a ho...
# 1019503  We went to Craigie on Main for my graduation d...
# 1019504  Come here if you want to see a replica of the ...
# ...                                                    ...
# 1274370  Falafel that's actually fresh, soft, and hot! ...
# 1274371  Best Italian in town period.  You just cannot ...
# 1274372  Amazing, filling donuts that are cheaper than ...
# 1274373  Good coffee, chill vibe, no free internet. P.S...
# 1274374  As the only place to get a decent sandwich nea...
#
#                         date  \
# 1019500  2009-02-27 08:38:22
# 1019501  2016-11-09 00:42:38
# 1019502  2016-01-16 18:46:29
# 1019503  2012-05-26 19:23:10
# 1019504  2011-05-21 17:36:05
# ...                      ...
# 1274370  2012-05-10 18:03:14
# 1274371  2017-09-27 20:15:22
# 1274372  2014-11-23 03:12:52
# 1274373  2012-04-18 23:53:09
# 1274374  2012-08-28 20:16:28
#
#                                                  clean_msg  words  \
# 1019500  friend swung sibling rivalry dessert dinner ad...     55
# 1019501  boy average expensive meal 30 crab cake shrimp...     16
# 1019502  excellent place grab breakfast horribly rainy ...     70
# 1019503  went craigie main graduation dinner initially ...    380
# 1019504  come want see replica bar tv show purchase sou...     42
# ...                                                    ...    ...
# 1274370  falafel thats actually fresh soft hot youre ne...     31
# 1274371  best italian town period cannot go wrong place...     27
# 1274372  amazing filling donuts cheaper one dunkin donu...     41
# 1274373  good coffee chill vibe free internet ps super ...     14
# 1274374  place get decent sandwich near work end eating...     60
#
#                                             sentiment_dict
# 1019500  [{'label': 'POSITIVE', 'score': 0.997495472431...
# 1019501  [{'label': 'NEGATIVE', 'score': 0.939373910427...
# 1019502  [{'label': 'POSITIVE', 'score': 0.509173989295...
# 1019503  [{'label': 'POSITIVE', 'score': 0.660971760749...
# 1019504  [{'label': 'NEGATIVE', 'score': 0.997037887573...
# ...                                                    ...
# 1274370  [{'label': 'POSITIVE', 'score': 0.997953057289...
# 1274371  [{'label': 'POSITIVE', 'score': 0.964645028114...
# 1274372  [{'label': 'POSITIVE', 'score': 0.961159706115...
# 1274373  [{'label': 'POSITIVE', 'score': 0.996456444263...
# 1274374  [{'label': 'NEGATIVE', 'score': 0.642932295799...
#
# [254875 rows x 14 columns]

# %%
user_reviews_state_b5.to_pickle('./data/user_reviews_state_b5.pkl')

# %%
# %%time
user_reviews_state_b6['sentiment_dict'] = user_reviews_state_b6['clean_msg'].apply(lambda review: sentiment(review, truncation=True))
user_reviews_state_b6
# Out:
# Wall time: 7h 16min 43s
#          level_0    index               review_id                 user_id  \
# 1274375  1274375  7209234  KWSAYwWRXxbEs7eDXnZASw  Bc4GZfIUJu9363QQVACZVA
# 1274376  1274376  7209235  _6DifNONvHahJP_K9re_ww  6Mw5RwKjVaBSyP1nR0j9iw
# 1274377  1274377  7209245  eMD3HPImmUjs7BD3d0UyQQ  1R5Q9RYWyLA25oc-jVgpCQ
# 1274378  1274378  7209246  ftxfFrl_AJK-vsYl3UXaMg  dHgttjMtwU2yLuzpagnxKg
# 1274379  1274379  7209253  A8UR12Xse6SNNDXMdyfYEw  v9PVFhU_SvJwVlF_iv1s7w
# ...          ...      ...                     ...                     ...
# 1529245  1529245  8635381  DwGTdEcpVg9n7juq5rRFyA  9U30DANobkrn3Zlu6T9p6Q
# 1529246  1529246  8635386  Kc9bVQvMwUjehqhPkDBEvQ  wbhaPKJIYryGrCBVWJ7Nmg
# 1529247  1529247  8635388  czSnN2gwIyfqOVt2qcfi-g  1WGPvc_cDXt-IPVNqg5BOA
# 1529248  1529248  8635395  1LrBZbLNfkBsFrHwEBlfSg  fYkURme6Piqxu4qUjQV3PQ
# 1529249  1529249  8635396  F5eAqFzDEyU6q5bBuCjglg  7Ey9Xc2hC4obn7spjp1mHw
#
#                     business_id  stars  useful  funny  cool  \
# 1274375  udMDXtKnJMQecjnqipfbSQ    5.0       0      0     0
# 1274376  IOpXmCLtQ3OHvvMzOXaPbg    4.0       0      0     0
# 1274377  8p7gjoSXCqFga82Ei7LTVg    4.0       0      0     0
# 1274378  pD3l4wyuebOvbrxBrXmXxQ    4.0       0      1     0
# 1274379  ZKJVjVofznYh1x2kSTyfGw    4.0       0      0     0
# ...                         ...    ...     ...    ...   ...
# 1529245  biYgFkftCPue7g3upflUOg    4.0       2      0     0
# 1529246  cgNDiWCaSlqqxx1A6r65bA    5.0       0      0     0
# 1529247  FxveeHL_B0Kkz1KjPKyF3A    5.0       0      0     0
# 1529248  gEQxTJDoJYaW0l_6FYtf8g    5.0       1      0     0
# 1529249  PrTS_wxKNxf0kRTOcboeIw    1.0       1      1     0
#
#                                                       text  \
# 1274375  Go-to place for cheap sushi! I always come her...
# 1274376  I had a late lunch there twice and both times ...
# 1274377  I've ordered plenty of delivery from this plac...
# 1274378  We went there last night. It was pretty good. ...
# 1274379  This place has the best nachos in Southie...fo...
# ...                                                    ...
# 1529245  Trade's 3 star average is baffling. I get some...
# 1529246  Please support this place! They are trying to ...
# 1529247  They make a really great burger for the league...
# 1529248  Best pizza in the neighborhood!!! Love the thi...
# 1529249  This was absolutely the most egregious display...
#
#                         date  \
# 1274375  2013-01-18 05:46:24
# 1274376  2011-06-12 20:05:24
# 1274377  2018-03-30 16:07:00
# 1274378  2014-10-19 20:33:51
# 1274379  2011-11-19 01:31:34
# ...                      ...
# 1529245  2012-01-04 01:40:36
# 1529246  2021-01-17 02:04:29
# 1529247  2021-01-18 02:55:18
# 1529248  2020-12-05 21:32:45
# 1529249  2020-10-23 23:28:09
#
#                                                  clean_msg  words  \
# 1274375  goto place cheap sushi always come friendfamil...     79
# 1274376  late lunch twice times pretty quiet food came ...     26
# 1274377  ive ordered plenty delivery place major mistak...     19
# 1274378  went last night pretty good 2 kinds oysters pe...     34
# 1274379  place best nachos southiefor whatever thats wo...     22
# ...                                                    ...    ...
# 1529245  trades 3 star average baffling get people whin...    154
# 1529246  please support place trying everything right p...     21
# 1529247  make really great burger league theyre playing...     23
# 1529248  best pizza neighborhood love crust moderate am...     10
# 1529249  absolutely egregious display incompetence ever...    145
#
#                                             sentiment_dict
# 1274375  [{'label': 'NEGATIVE', 'score': 0.983477294445...
# 1274376  [{'label': 'POSITIVE', 'score': 0.998069226741...
# 1274377  [{'label': 'POSITIVE', 'score': 0.755156755447...
# 1274378  [{'label': 'POSITIVE', 'score': 0.999579370021...
# 1274379  [{'label': 'NEGATIVE', 'score': 0.999425411224...
# ...                                                    ...
# 1529245  [{'label': 'NEGATIVE', 'score': 0.958492338657...
# 1529246  [{'label': 'POSITIVE', 'score': 0.974796473979...
# 1529247  [{'label': 'NEGATIVE', 'score': 0.661733031272...
# 1529248  [{'label': 'POSITIVE', 'score': 0.992046713829...
# 1529249  [{'label': 'NEGATIVE', 'score': 0.998139977455...
#
# [254875 rows x 14 columns]

# %%
user_reviews_state_b6.to_pickle('./data/user_reviews_state_b6.pkl')

# %% [markdown]
# ## Merge all the user reviews for state MA and OR

# %%
user_reviews_portland = pd.read_pickle('./data/user_review_sentiment.pkl')

# %%
user_reviews_portland.drop(labels=['sentiment_label','sentiment_score','sentiment_final'], axis = 1, inplace =True)

# %%
user_reviews_b1 = pd.read_pickle('./data/user_reviews_state_b1.pkl')

# %%
user_reviews_b2 = pd.read_pickle('./data/user_reviews_state_b2.pkl')

# %%
user_reviews_b3 = pd.read_pickle('./data/user_reviews_state_b3.pkl')

# %%
user_reviews_b4 = pd.read_pickle('./data/user_reviews_state_b4.pkl')

# %%
user_reviews_b5 = pd.read_pickle('./data/user_reviews_state_b5.pkl')

# %%
user_reviews_b6 = pd.read_pickle('./data/user_reviews_state_b6.pkl')

# %%
user_reviews_final = pd.concat([user_reviews_portland, user_reviews_b1, user_reviews_b2, user_reviews_b3, user_reviews_b4, user_reviews_b5, user_reviews_b6], ignore_index=True)

# %%
user_reviews_final.drop(labels=['index','level_0'], axis=1, inplace = True)

# %%
user_reviews_final.to_pickle('./data/user_reviews_final.pkl')

# %% [markdown]
# ### Create New column for distilbert analysis 'label'

# %%
user_reviews_final['sentiment_label'] = user_reviews_final['sentiment_dict'].apply(lambda score_dict: score_dict[0]['label'])

# %%
## Label POSITIVE = 1 , NEGATIVE = -1

user_reviews_final['sentiment_label'].replace({'POSITIVE': 1, 'NEGATIVE': -1},inplace=True)

# %% [markdown]
# ### Create New column for distilbert analysis 'score'

# %%
user_reviews_final['sentiment_score'] = user_reviews_final['sentiment_dict'].apply(lambda score_dict: score_dict[0]['score'])

# %%
# Multiply sentiment_label * sentiment_score to get compound score.
user_reviews_final['sentiment_final'] = user_reviews_final['sentiment_label'] * user_reviews_final['sentiment_score']

# %%
### Export user_reviews with sentiment score
user_reviews_final.to_pickle('./data/user_reviews_sentiment_final.pkl')

# %% [markdown]
# ### Calculate the mean sentiment score for each restaurants groupby 'businessid'

# %%
user_reviews_final.groupby(by='business_id')['sentiment_final'].mean()
# Out:
# business_id
# --6COJIAjkQwSUZci_4PJQ    0.594357
# --UNNdnHRhsyFUbDgumdtQ    0.417455
# -00d-Qb0q2TcWn-8LBHDZg   -0.273694
# -0Gbsd7ztvTyFpl7jF0DIw    0.297091
# -0iqnv7MjKrgh7Q7bYRlUQ   -0.000902
#                             ...
# zyNQhunb1mcSUUbnqVcU1w   -0.148889
# zyauuvAYdVweBK4L7wBRmw   -0.118130
# zzO0rjxjVAutcqFnI4VvAg   -0.483112
# zzcdycb7S42VnnZkwE4yNA   -0.728696
# zzpmoTVq4yn86U7ArHyFBQ    0.380740
# Name: sentiment_final, Length: 18093, dtype: float64

# %%
# Create dataframe for the mean sentiment score
sentiment_score = user_reviews_final.groupby(by='business_id')['sentiment_final'].mean().to_frame().reset_index()

# %%
sentiment_score.head()
# Out:
#               business_id  sentiment_final
# 0  --6COJIAjkQwSUZci_4PJQ         0.594357
# 1  --UNNdnHRhsyFUbDgumdtQ         0.417455
# 2  -00d-Qb0q2TcWn-8LBHDZg        -0.273694
# 3  -0Gbsd7ztvTyFpl7jF0DIw         0.297091
# 4  -0iqnv7MjKrgh7Q7bYRlUQ        -0.000902

# %%
sentiment_score.describe()
# Out:
#        sentiment_final
# count     18093.000000
# mean          0.079334
# std           0.383843
# min          -0.999254
# 25%          -0.170261
# 50%           0.118951
# 75%           0.353336
# max           0.999456

# %%
## Export sentiment_score
sentiment_score.to_csv('./data/sentiment_score.csv', index =False)
